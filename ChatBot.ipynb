# %% [markdown]
# https://www.capitalone.com/tech/machine-learning/how-to-finetune-sbert-for-question-matching/

# %%
# !pip install sentence-transformers
# !pip install transformers
# !pip install torch
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: nltk in c:\users\boyuan zhang\anaconda3\lib\site-packages (from sentence-transformers) (3.6.5)
# Requirement already satisfied: scipy in c:\users\boyuan zhang\anaconda3\lib\site-packages (from sentence-transformers) (1.9.0)
# Collecting torchvision
#   Using cached torchvision-0.13.1-cp39-cp39-win_amd64.whl (1.1 MB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: torch>=1.6.0 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from sentence-transformers) (1.12.1)
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
# Requirement already satisfied: scikit-learn in c:\users\boyuan zhang\anaconda3\lib\site-packages (from sentence-transformers) (0.24.2)
# Requirement already satisfied: numpy in c:\users\boyuan zhang\anaconda3\lib\site-packages (from sentence-transformers) (1.20.3)
# Requirement already satisfied: tqdm in c:\users\boyuan zhang\anaconda3\lib\site-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: requests in c:\users\boyuan zhang\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: filelock in c:\users\boyuan zhang\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.10.0.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Using cached tokenizers-0.12.1-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.8.3)
# Requirement already satisfied: colorama in c:\users\boyuan zhang\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.4)
# Requirement already satisfied: click in c:\users\boyuan zhang\anaconda3\lib\site-packages (from nltk->sentence-transformers) (8.0.3)
# Requirement already satisfied: joblib in c:\users\boyuan zhang\anaconda3\lib\site-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from torchvision->sentence-transformers) (8.4.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers, torchvision, sentencepiece, sentence-transformers
# Successfully installed huggingface-hub-0.9.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.12.1 torchvision-0.13.1 transformers-4.21.2
# Requirement already satisfied: transformers in c:\users\boyuan zhang\anaconda3\lib\site-packages (4.21.2)
# Requirement already satisfied: requests in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (2.26.0)
# Requirement already satisfied: filelock in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (3.3.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (2021.8.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (1.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (0.9.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from transformers) (21.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\boyuan zhang\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\boyuan zhang\anaconda3\lib\site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: torch in c:\users\boyuan zhang\anaconda3\lib\site-packages (1.12.1)
# Requirement already satisfied: typing-extensions in c:\users\boyuan zhang\anaconda3\lib\site-packages (from torch) (3.10.0.2)

# %%
# sentence-transformers==1.0.4, torch==1.7.0.
import spacy
import random
from collections import defaultdict
from sentence_transformers import SentenceTransformer, SentencesDataset
from sentence_transformers.losses import TripletLoss
from sentence_transformers.readers import LabelSentenceReader, InputExample
from torch.utils.data import DataLoader


# for complex model
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer
import torch
import numpy as np
import pandas as pd
from scipy import spatial

import warnings
warnings.simplefilter('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\BOYUAN~1\AppData\Local\Temp/ipykernel_45328/2364621481.py in <module>
#       1 # sentence-transformers==1.0.4, torch==1.7.0.
# ----> 2 import spacy
#       3 import random
#       4 from collections import defaultdict
#       5 from sentence_transformers import SentenceTransformer, SentencesDataset
#
# ModuleNotFoundError: No module named 'spacy'

# %%
def triplets_from_labeled_dataset(input_examples):
    # Create triplets for a [(label, sentence), (label, sentence)...] dataset
    # by using each example as an anchor and selecting randomly a positive instance with the same label and a negative instance with a different label
    """During each iteration of the fine-tuning process, we select an anchor vector v1 to focus on. We then select a positive and a negative data point for 
    comparison: v2 from the same group as v1 and v3 from a different group. We then minimize the distance between v1 and v2 (anchor and positive) while maximizing
     the distance between v1 and v3 (anchor and negative). The loss function for this optimization is known as triplet loss."""
     
    triplets = []
    label2sentence = defaultdict(list)
    for inp_example in input_examples:
        label2sentence[inp_example.label].append(inp_example)

    for inp_example in input_examples:
        anchor = inp_example

        if len(label2sentence[inp_example.label]) < 2: #We need at least 2 examples per label to create a triplet
            continue

        positive = None
        while positive is None or positive.guid == anchor.guid:
            positive = random.choice(label2sentence[inp_example.label])

        negative = None
        while negative is None or negative.label == anchor.label:
            negative = random.choice(input_examples)

        triplets.append(InputExample(texts=[anchor.texts[0], positive.texts[0], negative.texts[0]]))

    return triplets

# %%
# Load pre-trained model - we are using the original Sentence-BERT for this example.
sbert_model = SentenceTransformer('bert-base-nli-stsb-mean-tokens')

# Set up data for fine-tuning 
sentence_reader = LabelSentenceReader(folder='/content')

data_list = sentence_reader.get_examples(filename='Copy of Test_QA_data_ver2_0704  - Sheet1.tsv')
triplets = triplets_from_labeled_dataset(input_examples=data_list)
finetune_data = SentencesDataset(examples=triplets, model=sbert_model)
finetune_dataloader = DataLoader(finetune_data, shuffle=True, batch_size=16)

# Initialize triplet loss
loss = TripletLoss(model=sbert_model)

# Fine-tune the model
sbert_model.fit(train_objectives=[(finetune_dataloader, loss)], epochs=4, output_path='bert-base-nli-stsb-mean-tokens-rmds')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.98k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/630 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/409 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/44 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/44 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/44 [00:00<?, ?it/s]

# %%
#### changes made here
#### import our default text
df = pd.read_csv('/content/Copy of Test_QA_data_ver2_0704  - Sheet1.tsv' , sep='\t', header=None)
colnames = ['number', 'question', 'a', 'b', 'c']
df_2 = pd.read_csv('/content/Test_QA_data_ver2_0704 (with category) - Sheet1.tsv', sep='\t', header=0, names=colnames)

# import the trained model
rmds_model = SentenceTransformer('bert-base-nli-stsb-mean-tokens-rmds')

# select the default answer
q_tem = df.groupby(0).apply(lambda x: x.iloc[:-1] if len(x)>1 else x).reset_index(drop=True)
answer_tem = df.groupby(0).apply(lambda x: x.iloc[-1] if len(x)>1 else x).reset_index(drop=True)
corresponding_answer = pd.merge(left=q_tem, right=answer_tem, how="left", left_on=0, right_on=0)['1_y'].tolist()

# same filter for question number
q_num = q_tem.iloc[:,0].tolist()

# select the default questions
question_text = df.groupby(0).apply(lambda x: x.iloc[:-1] if len(x)>1 else x).reset_index(drop=True)[1].tolist()

#question_text are encoded by calling model.encode()
question_embeddings = rmds_model.encode(question_text)

#Print the embeddings
#for sentence, embedding in zip(question_text, question_embeddings):
    #print("Sentence:", sentence)
    #print("Embedding:", embedding)
    #print("###################################")
    #print("")

# %%
 ## getting categories 
 ## grouped by question number
 ## have duplicates if different question number shares same category

cat_a = df_2.groupby(['number']).apply(lambda x: x.iloc[0]).reset_index(drop=True).iloc[:,2].values.tolist()
cat_b = df_2.groupby(['number']).apply(lambda x: x.iloc[0]).reset_index(drop=True).iloc[:,3].values.tolist()
cat_c = df_2.groupby(['number']).apply(lambda x: x.iloc[0]).reset_index(drop=True).iloc[:,4].values.tolist()

## non-dup category list as below

cat_a_no_dup = [*set(cat_a)]
cat_b_no_dup = [*set(cat_b)]
cat_c_no_dup = [*set(cat_c)]

# %%
######## auto input user questions

# input user question
new_question = """where to find rmds?"""
## embedding question
encoded_question = rmds_model.encode([new_question])

## calculate the distance
distances = spatial.distance.cdist(np.array(encoded_question), question_embeddings, 'cosine')[0]
results = zip(range(len(distances)), distances)
results = sorted(results, key=lambda x: x[1])

for idx, distance in results[0:3]: # just getting top 1
    if 1-distance>0.5:
      print(f"Your answer:")
      # print(question_texts[idx])
      # print(f"cosine_score:{1-distance}, {corresponding_answer[idx]}")
      print(corresponding_answer[idx])
      break
    else:
      print(f"Sorry I don't understand this, but do you mean to ask this: {question_text[idx]}")
      break
# Out:
# Your answer:
# To learn more about us, please visit our website: https://grmds.org/

# %%
backup_qlist = [ 
    """
      Do you know we also offer a wide range of courses, 
      starting from data science, business analytics, all the way to computer science and AI related. \n
      No matter if you are just beginners who are interested in the filed of data analysis, 
      or professionals who intend to puruse in computational finance, you should defnitely check it out at the courses offered at RMDS! \n
      You can type 'what courses do you have' below to ask for more information!""",
    """ 
      Want to attend some fun events while enriching your understandings in data and technologies? We've got a summer refresher for you!
      Let's meet with some aswesome speakers and enthusiasts at the IMDATA 2022 conference! \n
      Here you could have a taste in the combo of NFT and cryoptograph, take a look at ultilizing AI in data sciences. 
      You can type 'IMDATA 2022' below to learn more about this event you defnitely shouldn't miss! \n""", 
    """
        Did you know, through our NFT marketplace, our community members have access to tools and 
        resources that enhance their research and increase the success rate of their work. \n
        Haven't heard about NFT or our marketplace? Definitely give it a look by typing 'NFT' or 'NFT Marketplace' below to ask me more!""",
    """
        promote membership 
     """,
     """
        introduce nft
     """,
     """
        webinars (there are free recordings available)
     """,
     """
        competition / major event (find latest)
     """,]

# %%
#StopWords function
## add points if word appears in category b
## subtract points if words are too 'weird' for making a question
nlp = spacy.load('en_core_web_sm')

def CleanStopWords(question):
  cate_B_list = [str(x).lower().split(' /') for x in df_2['b']]
  list_B = []
  hate_word_list = ['hate','detestation','disgust','enmity','hate','hatred','horror','loath','malice','disgust','revolt']
  for i in cate_B_list:
    for j in i:
      if j not in list_B and j != 'nan':
        list_B.append(j)
  StopWords = ['is','are','be','should','does','do','can','that','to','for','on','at','from','by','and', 'in']
  line = nlp(question)
  question_tokens = [str(token).lower() for token in line if str(token) not in StopWords]
  bonus_count = 0
  hate_count = 0
  bonus_list = []
  for i in range(len(question_tokens)):
    
    if question_tokens[i] in list_B:
      bonus_list.append(question_tokens[i])
      bonus_count+=1
      
    elif i < len(question_tokens)-1:
      if question_tokens[i]+' '+question_tokens[i+1] in list_B:
        bonus_list.append(question_tokens[i]+' '+question_tokens[i+1])
        bonus_count+=1
        
    

  for token in question_tokens:
    if token in hate_word_list:
      hate_count+=1
  return ' '.join(question_tokens), bonus_count, bonus_list, hate_count 

CleanStopWords('I like big data!')
# Out:
# ('i like big data !', 1, ['big data'], 0)

# %%
# question cannot be identified (special case)
def QA_special(answer_text, response, relevant_q):
    flag_1 = True
    while flag_1:
    # input user question
      if response in ["Yes", "Y", "yes", "y", "yep", "yea", "yeah", "YES"]: #provide answers
        print(f'\n{answer_text}')
        print(f"\nDo you want to know more about the following questions? You can type the question number, other questions you have or 'no' to end our conversation\n")
        
        number = 1
        for question in relevant_q:
          if number == 3:
            print("******** Here are more you might want to know ********\n")
          print(f'{number}. {question}\n')
          number += 1
        flag_1 = False
        return relevant_q
      
      elif response in ["No", "NO", "no", "nope", "nah", "N", "n"]: # suggest further assistance
        print("Sorry I don't understand your question, but you can email us at info@rmdslab.com or give us a call at 1-626-432-7266 for more information!\n")
        flag_1 = False
        return -1
      
      else: #invalid input from user
        response = input("Please try input again. You can try type in 'yes' or 'no'.\n")

# %%
cate_B_list = [str(x).lower().split(' /') for x in df_2['b']]
list_B = []
for i in cate_B_list:
  for j in i:
    if j not in list_B and j != 'nan':
      list_B.append(j)
list_B
# Out:
# ['rmds',
#  ' mission',
#  ' goal',
#  'service',
#  ' product',
#  'study',
#  ' course',
#  ' class',
#  ' training',
#  'event ',
#  'event',
#  'project portal',
#  'data science portfolio',
#  'rmds exchange',
#  'nft market',
#  'rm4es',
#  ' workflow',
#  'researchmap',
#  'ecosystem',
#  'big data',
#  ' ai',
#  ' business',
#  ' data science',
#  'financial technology',
#  ' cryptocurrency',
#  'ai bias',
#  ' surveillance',
#  'data analysis',
#  'cdi',
#  'ai',
#  ' ethics',
#  ' decision making',
#  'webinar series',
#  'covid',
#  ' literature review',
#  ' model',
#  'python',
#  'knime',
#  ' basic',
#  'chatbot',
#  ' healthcare',
#  'machine learning',
#  ' ml',
#  'grmds',
#  'imdata',
#  'quaterly competition',
#  'nft',
#  'nft exchange',
#  'upskill program',
#  ' pi program',
#  ' internship',
#  'impact score',
#  'recommendation system',
#  'practical data science training',
#  'pre-conference training']

# %%
'big data' in list_B
# Out:
# True

# %%
# convert it to a function
def QA_bot(input_question,question_embeddings, corresponding_answer):
  # input user question
  new_question, bonus_count, bonus_list, hate_count = CleanStopWords(input_question)
  bonus_list_flatten = ' '.join(bonus_list)
  ## embedding question
  encoded_question = rmds_model.encode([new_question])

  ## calculate the distance
  distances = spatial.distance.cdist(np.array(encoded_question), question_embeddings, 'cosine')[0]
  results = zip(range(len(distances)), distances)
  results = sorted(results, key=lambda x: x[1])
  print(results[0:3])

  ## getting index 
  idx = results[0][0]

  ## getting category b
  category_b = [x for x in df_2.b.tolist() if pd.isna(x)==False][idx]

  ## getting category c (if non-null: null = -1)
  category_c = [x for x in df_2.c.tolist() if pd.isna(x)==False][idx]
  flag_cat_c = False
  if category_c.isnumeric():
    flag_cat_c = True

  ## getting question number
  question_num = q_num[idx]

  ## getting relevant questions 
  relevant_q = df_2.loc[(df_2['b'] == category_b) & (df_2['number'] != question_num)].iloc[:, 0:2]
  relevant_q = relevant_q.groupby(['number']).apply(lambda x: x.iloc[0]).reset_index(drop=True).iloc[:,1].values.tolist()
  if len(relevant_q) >= 2 and flag_cat_c==True:
    relevant_q = relevant_q[:2]

  ## getting question from category c (if possible)
  if flag_cat_c:
    more_q = df_2.loc[(df_2['c'] != -1) & (df_2['c'] == category_c) & (df_2['b'] != category_b)].iloc[:, 0:2]
    more_q = more_q.groupby(['number']).apply(lambda x: x.iloc[0]).reset_index(drop=True).iloc[:,1].values.tolist()[:2]

    for question in more_q:
      relevant_q.append(question)
  
  ## pull up from the backup list
  '''
  while len(relevant_q) < 15:
    question = backup_qlist[random.randint(0,8)]
    while question in relevant_q or question == input_question:
      question = backup_qlist[random.randint(0,8)]
    relevant_q.append(question)
'''
  
  ##########################################################
  for idx, distance in results[0:1]: # just getting top 1
      if bonus_count > 0:
        distance -= bonus_count * 0.3
        print(distance)
      if hate_count > 0:
        distance += hate_count * 0.5
      
      ############### test on this boundary value
      ##### use all questions from the sheet to find max / min score it could achieve
      #### when should the chatbot reply
      
      if distance < 0.3:   # print the answer
        print(corresponding_answer[idx])
        number = 1
        print(f"\nDo you want to know more about the following questions? You can type the question number, other questions you have or 'no' to end our conversation\n")
        for question in relevant_q:
          if number == 3:
            print("******** Here are more you might want to know ********\n")
          print(f'{number}. {question}\n')
          number += 1

        ## randomly pop up topics to direct conversation to other directions 25% probability
        if random.randint(1,4) == 4 and len(backup_qlist) != 0:
          print(backup_qlist.pop(random.randint(0, len(backup_qlist))))
        return relevant_q

      else:
        response = input(f"""\nSorry I don't understand this, but do you mean to ask this : {question_text[idx]}\nOR\nDid you want to know more about: {bonus_list_flatten}\n""")
        return QA_special(corresponding_answer[idx], response, relevant_q)

QA_bot("AI!", question_embeddings, corresponding_answer)
# Out:
# [(371, 0.3004916874134952), (372, 0.33563935863140504), (395, 0.4289983173409876)]
# 0.000491687413495201
# The followings are the courses we have: 1. Financial Technology, Cryptocurrency & AI  2. AI Bias & Surveillance: Recognition, Analysis, and Prediction  3. AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems  4.  Creation of Specialized AI Assistant for Healthcare Industry.
#
# Do you want to know more about the following questions? You can type the question number, other questions you have or 'no' to end our conversation
#
# 1. where could I find course about AI?
# ['where could I find course about AI?']

# %%
############## bert similar version ##############
question = input("\nPlease enter your question: \n")

while True:
  # question_answer(question)
  result = QA_bot(question, question_embeddings, corresponding_answer)

  flag = True
  flag_N = False
  while flag:
    if result == -1:  # question cannot be identified
      response = input("\nDo you have other question? You can type your question as below\n")
      while not (chr.isalpha() or chr.isspace() or chr=='?' for chr in response):
        response = input("Please try input again. You can try typing your own question here.\n")
    
    else:  # user should type in number to choose
      response = input(f"\n")
      # user choose relevant question
      if response.isnumeric():
        while not (0 < int(response) and int(response) <= len(result)): 
          response = input(f"Please try input again. You can type in numbers from 1 to {len(result)}.\n")
        question = result[int(response)-1]
        break

    # user wants to end conversation
    if response in ["No", "no","nothing", "that's it","N"]: #user want to end
        print("\nSee you next time!")
        flag = False
        flag_N = True
        break    
    
    # user correctly type in their own question
    question = response
    flag = False
  if flag_N == True:
    break
# Out:
# Please enter your question:
# dd
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BOYUAN~1\AppData\Local\Temp/ipykernel_45328/2639207386.py in <module>
#       4 while True:
#       5   # question_answer(question)
# ----> 6   result = QA_bot(question, question_embeddings, corresponding_answer)
#       7
#       8   flag = True
#
# NameError: name 'QA_bot' is not defined

# %%
##########################################################################################################

# %%
q_tem
# Out:
#        0                                                  1           2  \
# 0      1                                  What is RMDS Lab?  who are we
# 1      1                                      What is RMDS?  who are we
# 2      1                                  RMDS Lab is what?  who are we
# 3      1                                       who are you?  who are we
# 4      1                                          RMDS Lab?  who are we
# ..   ...                                                ...         ...
# 502  188          how does Pre-Conference Training help me?         why
# 503  188   what can I benefit from Pre-Conference Training?         why
# 504  188   what can I benefit from Pre-Conference Training?         why
# 505  189  where can I learn more about Pre-Conference Tr...       where
# 506  189         where to find out Pre-Conference Training?       where
#
#                            3      4
# 0      RMDS / mission / goal  grmds
# 1      RMDS / mission / goal  grmds
# 2      RMDS / mission / goal  grmds
# 3      RMDS / mission / goal  grmds
# 4      RMDS / mission / goal  grmds
# ..                       ...    ...
# 502  Pre-Conference Training     -1
# 503  Pre-Conference Training     -1
# 504  Pre-Conference Training     -1
# 505  Pre-Conference Training     -1
# 506  Pre-Conference Training     -1
#
# [507 rows x 5 columns]

# %%
df_2 = pd.read_csv('/content/Test_QA_data_ver2_0704 (with category) - Sheet1.tsv', sep='\t', header=None)
df_2
# Out:
#        0                                                  1           2  \
# 0      1                                  What is RMDS Lab?  who are we
# 1      1                                      What is RMDS?  who are we
# 2      1                                  RMDS Lab is what?  who are we
# 3      1                                       who are you?  who are we
# 4      1                                          RMDS Lab?  who are we
# ..   ...                                                ...         ...
# 691  188   what can I benefit from Pre-Conference Training?         why
# 692  188  The Pre-conferencel training offers you a bett...         NaN
# 693  189  where can I learn more about Pre-Conference Tr...       where
# 694  189         where to find out Pre-Conference Training?       where
# 695  189  Please check our websites for more details: ht...         NaN
#
#                            3      4
# 0      RMDS / mission / goal  grmds
# 1      RMDS / mission / goal  grmds
# 2      RMDS / mission / goal  grmds
# 3      RMDS / mission / goal  grmds
# 4      RMDS / mission / goal  grmds
# ..                       ...    ...
# 691  Pre-Conference Training     -1
# 692                      NaN    NaN
# 693  Pre-Conference Training     -1
# 694  Pre-Conference Training     -1
# 695                      NaN    NaN
#
# [696 rows x 5 columns]

# %%
answer_tem
# Out:
#        0                                                  1    2    3    4
# 0      1  Global Association for Research Methods and Da...  NaN  NaN  NaN
# 1      2  We offer our user a global platform which enab...  NaN  NaN  NaN
# 2      3  To learn more about us, please visit our websi...  NaN  NaN  NaN
# 3      4  RMDS is a pioneer of impact scoring, and devel...  NaN  NaN  NaN
# 4      5  we have a lot of services such as GRMDS Ecosys...  NaN  NaN  NaN
# ..   ...                                                ...  ...  ...  ...
# 184  185  Please check out our websites for more details...  NaN  NaN  NaN
# 185  186  Prior to the annually IMDATA conference, we of...  NaN  NaN  NaN
# 186  187  The Pre-conference is for anyone in need to be...  NaN  NaN  NaN
# 187  188  The Pre-conferencel training offers you a bett...  NaN  NaN  NaN
# 188  189  Please check our websites for more details: ht...  NaN  NaN  NaN
#
# [189 rows x 5 columns]

# %%
pd.merge(left=q_tem, right=answer_tem, how="left", left_on=0, right_on=0)
# Out:
#        0                                                1_x         2_x  \
# 0      1                                  What is RMDS Lab?  who are we
# 1      1                                      What is RMDS?  who are we
# 2      1                                  RMDS Lab is what?  who are we
# 3      1                                       who are you?  who are we
# 4      1                                          RMDS Lab?  who are we
# ..   ...                                                ...         ...
# 502  188          how does Pre-Conference Training help me?         why
# 503  188   what can I benefit from Pre-Conference Training?         why
# 504  188   what can I benefit from Pre-Conference Training?         why
# 505  189  where can I learn more about Pre-Conference Tr...       where
# 506  189         where to find out Pre-Conference Training?       where
#
#                          3_x    4_x  \
# 0      RMDS / mission / goal  grmds
# 1      RMDS / mission / goal  grmds
# 2      RMDS / mission / goal  grmds
# 3      RMDS / mission / goal  grmds
# 4      RMDS / mission / goal  grmds
# ..                       ...    ...
# 502  Pre-Conference Training     -1
# 503  Pre-Conference Training     -1
# 504  Pre-Conference Training     -1
# 505  Pre-Conference Training     -1
# 506  Pre-Conference Training     -1
#
#                                                    1_y  2_y  3_y  4_y
# 0    Global Association for Research Methods and Da...  NaN  NaN  NaN
# 1    Global Association for Research Methods and Da...  NaN  NaN  NaN
# 2    Global Association for Research Methods and Da...  NaN  NaN  NaN
# 3    Global Association for Research Methods and Da...  NaN  NaN  NaN
# 4    Global Association for Research Methods and Da...  NaN  NaN  NaN
# ..                                                 ...  ...  ...  ...
# 502  The Pre-conferencel training offers you a bett...  NaN  NaN  NaN
# 503  The Pre-conferencel training offers you a bett...  NaN  NaN  NaN
# 504  The Pre-conferencel training offers you a bett...  NaN  NaN  NaN
# 505  Please check our websites for more details: ht...  NaN  NaN  NaN
# 506  Please check our websites for more details: ht...  NaN  NaN  NaN
#
# [507 rows x 9 columns]

# %%
corresponding_answer
# Out:
# ['Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.',
#  'We offer our user a global platform which enables them to meet, learn, and collaborate with fellow data science professionals to solve problems',
#  'We offer our user a global platform which enables them to meet, learn, and collaborate with fellow data science professionals to solve problems',
#  'To learn more about us, please visit our website: https://grmds.org/',
#  'To learn more about us, please visit our website: https://grmds.org/',
#  'RMDS is a pioneer of impact scoring, and developing data maturity assessment. With big data capabilities and advanced machine learning, RMDS provides financial companies and retailers with the best solutions for measuring store and unit performance.',
#  'RMDS is a pioneer of impact scoring, and developing data maturity assessment. With big data capabilities and advanced machine learning, RMDS provides financial companies and retailers with the best solutions for measuring store and unit performance.',
#  'RMDS is a pioneer of impact scoring, and developing data maturity assessment. With big data capabilities and advanced machine learning, RMDS provides financial companies and retailers with the best solutions for measuring store and unit performance.',
#  'we have a lot of services such as GRMDS Ecosystem, RM4E Workflow, ResearchMap, Project Portal, Data Science Portfolio, RMDS Exchange, and NFT Exchange. We also provide Internship opportunities, Impact Score, Recommendation System, Upskill Program, and Practical Data Science Training.',
#  'we have a lot of services such as GRMDS Ecosystem, RM4E Workflow, ResearchMap, Project Portal, Data Science Portfolio, RMDS Exchange, and NFT Exchange. We also provide Internship opportunities, Impact Score, Recommendation System, Upskill Program, and Practical Data Science Training.',
#  'we have a lot of services such as GRMDS Ecosystem, RM4E Workflow, ResearchMap, Project Portal, Data Science Portfolio, RMDS Exchange, and NFT Exchange. We also provide Internship opportunities, Impact Score, Recommendation System, Upskill Program, and Practical Data Science Training.',
#  'we have a lot of services such as GRMDS Ecosystem, RM4E Workflow, ResearchMap, Project Portal, Data Science Portfolio, RMDS Exchange, and NFT Exchange. We also provide Internship opportunities, Impact Score, Recommendation System, Upskill Program, and Practical Data Science Training.',
#  'we have a lot of services such as GRMDS Ecosystem, RM4E Workflow, ResearchMap, Project Portal, Data Science Portfolio, RMDS Exchange, and NFT Exchange. We also provide Internship opportunities, Impact Score, Recommendation System, Upskill Program, and Practical Data Science Training.',
#  'To learn more about us, please visit our website: https://grmds.org/',
#  'To learn more about us, please visit our website: https://grmds.org/',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'we have a lot of courses such as Big Data and AI to Improve Competency and Employability, Turning Business Problems into Data Science Problems, AI Bias & Surveillance: Recognition, Analysis, and Prediction. Learn through applying knowledge and skills to solve real-world problems. Learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price. To learn more about our courses and trainings, please visit our website: https://grmds.org/trainings',
#  'You can learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price.',
#  'You can learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price.',
#  'You can learn data science from the industrial leaders and well-known experts. Get certified by RMDS to evidence your competency with an affordable price.',
#  'RMDS courses are for people who aim to be more armed with a wide range of data science skills, which helps them to pursue career paths in data science-related fields.',
#  'RMDS courses are for people who aim to be more armed with a wide range of data science skills, which helps them to pursue career paths in data science-related fields.',
#  'To learn more about our courses and trainings, please visit our website: https://learn.grmds.org/',
#  'To learn more about our courses and trainings, please visit our website: https://learn.grmds.org/',
#  'The events that we have are Quarterly competion, anually IMDATA conference, and pre-conference training. Check out our websites for further information! Our last quaterly competition, NFT competition was held during Mar 21 ~ Apr 17 at https://grmds.org/comp/nft.   2022 IMDATA conference: https://grmds.org/imdata22.  Pre-Conference Training (2021): https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/',
#  'The events that we have are Quarterly competion, anually IMDATA conference, and pre-conference training. Check out our websites for further information! Our last quaterly competition, NFT competition was held during Mar 21 ~ Apr 17 at https://grmds.org/comp/nft.   2022 IMDATA conference: https://grmds.org/imdata22.  Pre-Conference Training (2021): https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/',
#  'The events that we have are Quarterly competion, anually IMDATA conference, and pre-conference training. Check out our websites for further information! Our last quaterly competition, NFT competition was held during Mar 21 ~ Apr 17 at https://grmds.org/comp/nft.   2022 IMDATA conference: https://grmds.org/imdata22.  Pre-Conference Training (2021): https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/',
#  'The events that we have are Quarterly competion, anually IMDATA conference, and pre-conference training. Check out our websites for further information! Our last quaterly competition, NFT competition was held during Mar 21 ~ Apr 17 at https://grmds.org/comp/nft.   2022 IMDATA conference: https://grmds.org/imdata22.  Pre-Conference Training (2021): https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/',
#  'The events that we have are Quarterly competion, anually IMDATA conference, and pre-conference training. Check out our websites for further information! Our last quaterly competition, NFT competition was held during Mar 21 ~ Apr 17 at https://grmds.org/comp/nft.   2022 IMDATA conference: https://grmds.org/imdata22.  Pre-Conference Training (2021): https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/',
#  'The events that we have are Quarterly competion, anually IMDATA conference, and pre-conference training. Check out our websites for further information! Our last quaterly competition, NFT competition was held during Mar 21 ~ Apr 17 at https://grmds.org/comp/nft.   2022 IMDATA conference: https://grmds.org/imdata22.  Pre-Conference Training (2021): https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/',
#  'Subscribe to our emailing list for our newsletter and promotions! Simply submit your email address, located on our footer.',
#  'Subscribe to our emailing list for our newsletter and promotions! Simply submit your email address, located on our footer.',
#  'Subscribe to our emailing list for our newsletter and promotions! Simply submit your email address, located on our footer.',
#  'Subscribe to our emailing list for our newsletter and promotions! Simply submit your email address, located on our footer.',
#  'RMDS holds events and workshops monthly in the greater Los Angeles area with people from research methodology, data science, data professional services, AI and computing joining the party.',
#  'People from research methodology, data science, data professional services, AI and computing all attend the RMDS events',
#  'Our workshop provides hands-on training with a flexible schedule that covers the latest trends in data science application across different industries',
#  'Our workshop provides hands-on training with a flexible schedule that covers the latest trends in data science application across different industries',
#  'Having hosted over 50 Meetups, we continue to serve our local LA chapter with monthly events and workshops. Subscribe to our emailing list for our newsletter and promotions! Simply submit your email address, located on our footer.',
#  'Having hosted over 50 Meetups, we continue to serve our local LA chapter with monthly events and workshops. Subscribe to our emailing list for our newsletter and promotions! Simply submit your email address, located on our footer.',
#  'To learn more, please visit our website: https://grmds.org/events',
#  'To learn more, please visit our website: https://grmds.org/events',
#  "Our project portal is a platform that allows RMDS members to upload and view fellow members' completed projects. These projects can include, but are not limited to, reports, raw data or preprocessed datasets, scripts written in Python, Scala, R, etc., and workflows.",
#  "Our project portal is a platform that allows RMDS members to upload and view fellow members' completed projects. These projects can include, but are not limited to, reports, raw data or preprocessed datasets, scripts written in Python, Scala, R, etc., and workflows.",
#  "Our project portal is a platform that allows RMDS members to upload and view fellow members' completed projects. These projects can include, but are not limited to, reports, raw data or preprocessed datasets, scripts written in Python, Scala, R, etc., and workflows.",
#  "Our project portal is a platform that allows RMDS members to upload and view fellow members' completed projects. These projects can include, but are not limited to, reports, raw data or preprocessed datasets, scripts written in Python, Scala, R, etc., and workflows.",
#  'Project Portal helps you to find and use datasets or completed projects uploaded by data scientist worldwide.',
#  'Project Portal helps you to find and use datasets or completed projects uploaded by data scientist worldwide.',
#  'Check out our websites for more information: https://grmds.org/resources',
#  'Check out our websites for more information: https://grmds.org/resources',
#  "The Data Scienec Portfolio is a session in the our users' dashboard page",
#  "The Data Scienec Portfolio is a session in the our users' dashboard page",
#  "The Data Scienec Portfolio is a session in the our users' dashboard page",
#  "The Data Scienec Portfolio is a session in the our users' dashboard page",
#  'To better exhibit your ability, RMDS Data Science Portfolio is here to help you to develop public evidence of your data science skills. The RMDS Data Science Portfolio allows you to present what you HAVE DONE, rather than tell people you CAN DO.',
#  'To better exhibit your ability, RMDS Data Science Portfolio is here to help you to develop public evidence of your data science skills. The RMDS Data Science Portfolio allows you to present what you HAVE DONE, rather than tell people you CAN DO.',
#  'RMDS Exchange, a point exchange system, which is one of the first for data science communities.',
#  'RMDS Exchange, a point exchange system, which is one of the first for data science communities.',
#  'RMDS Exchange, a point exchange system, which is one of the first for data science communities.',
#  'RMDS Exchange, a point exchange system, which is one of the first for data science communities.',
#  'RMDS Exchange allows you to effectively collaborate and communicate using our new chat feature! Users will earn and exchange points in order to receive constructive criticism and answers to their questions provided by our data science experts.',
#  'RMDS Exchange allows you to effectively collaborate and communicate using our new chat feature! Users will earn and exchange points in order to receive constructive criticism and answers to their questions provided by our data science experts.',
#  'To learn more, please visit our website: https://grmds.org/rmds-exchange',
#  'To learn more, please visit our website: https://grmds.org/rmds-exchange',
#  "An NFT marketplace launches from RMDS Lab for science and technology, which will speed up the world's science & technology innovation and help NFT businesses to sustain and expand.",
#  "An NFT marketplace launches from RMDS Lab for science and technology, which will speed up the world's science & technology innovation and help NFT businesses to sustain and expand.",
#  "An NFT marketplace launches from RMDS Lab for science and technology, which will speed up the world's science & technology innovation and help NFT businesses to sustain and expand.",
#  "An NFT marketplace launches from RMDS Lab for science and technology, which will speed up the world's science & technology innovation and help NFT businesses to sustain and expand.",
#  'NFT Market helps users to directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs. Users can confidently trade their assets with anonymous counterparts while avoiding any deception and risk of fraudulent activity. ',
#  'NFT Market helps users to directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs. Users can confidently trade their assets with anonymous counterparts while avoiding any deception and risk of fraudulent activity. ',
#  'NFT Market helps users to directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs. Users can confidently trade their assets with anonymous counterparts while avoiding any deception and risk of fraudulent activity. ',
#  'To learn more, please visit our website: rmdsNFT.com',
#  'To learn more, please visit our website: rmdsNFT.com',
#  'RM4E is our primary core practice at RMDS lab. The whole workflow processes follow by the 4Es, which stand for Equation, Estimation, Evaluation, Execution/Explanation. Here are some explanations for each of those steps: Equation - equations represent the models and frameworks for our research. They serve as a link between data and research ideas or designs. Estimation - estimation is the link between equations (models) and the data used for our research. They are the algorithms used to compute the parameters of our models. Evaluation - errors are used to evaluate the fit between models and data. These metrics evaluate the performance of our estimation methods and the produced models. Execution or explanation ‚Äì the explanation is the link between equations (models) and our intended research purposes. How we explain our results depends on our research purposes and also on the subject we are studying. Execution is the step that takes the created model for production, which is then utilized for decision making. ',
#  'RM4E is our primary core practice at RMDS lab. The whole workflow processes follow by the 4Es, which stand for Equation, Estimation, Evaluation, Execution/Explanation. Here are some explanations for each of those steps: Equation - equations represent the models and frameworks for our research. They serve as a link between data and research ideas or designs. Estimation - estimation is the link between equations (models) and the data used for our research. They are the algorithms used to compute the parameters of our models. Evaluation - errors are used to evaluate the fit between models and data. These metrics evaluate the performance of our estimation methods and the produced models. Execution or explanation ‚Äì the explanation is the link between equations (models) and our intended research purposes. How we explain our results depends on our research purposes and also on the subject we are studying. Execution is the step that takes the created model for production, which is then utilized for decision making. ',
#  'RM4E is our primary core practice at RMDS lab. The whole workflow processes follow by the 4Es, which stand for Equation, Estimation, Evaluation, Execution/Explanation. Here are some explanations for each of those steps: Equation - equations represent the models and frameworks for our research. They serve as a link between data and research ideas or designs. Estimation - estimation is the link between equations (models) and the data used for our research. They are the algorithms used to compute the parameters of our models. Evaluation - errors are used to evaluate the fit between models and data. These metrics evaluate the performance of our estimation methods and the produced models. Execution or explanation ‚Äì the explanation is the link between equations (models) and our intended research purposes. How we explain our results depends on our research purposes and also on the subject we are studying. Execution is the step that takes the created model for production, which is then utilized for decision making. ',
#  'RM4E is our primary core practice at RMDS lab. The whole workflow processes follow by the 4Es, which stand for Equation, Estimation, Evaluation, Execution/Explanation. Here are some explanations for each of those steps: Equation - equations represent the models and frameworks for our research. They serve as a link between data and research ideas or designs. Estimation - estimation is the link between equations (models) and the data used for our research. They are the algorithms used to compute the parameters of our models. Evaluation - errors are used to evaluate the fit between models and data. These metrics evaluate the performance of our estimation methods and the produced models. Execution or explanation ‚Äì the explanation is the link between equations (models) and our intended research purposes. How we explain our results depends on our research purposes and also on the subject we are studying. Execution is the step that takes the created model for production, which is then utilized for decision making. ',
#  'RM4E is our primary core practice at RMDS lab. The whole workflow processes follow by the 4Es, which stand for Equation, Estimation, Evaluation, Execution/Explanation. Here are some explanations for each of those steps: Equation - equations represent the models and frameworks for our research. They serve as a link between data and research ideas or designs. Estimation - estimation is the link between equations (models) and the data used for our research. They are the algorithms used to compute the parameters of our models. Evaluation - errors are used to evaluate the fit between models and data. These metrics evaluate the performance of our estimation methods and the produced models. Execution or explanation ‚Äì the explanation is the link between equations (models) and our intended research purposes. How we explain our results depends on our research purposes and also on the subject we are studying. Execution is the step that takes the created model for production, which is then utilized for decision making. ',
#  'RM4E is our primary core practice at RMDS lab. The whole workflow processes follow by the 4Es, which stand for Equation, Estimation, Evaluation, Execution/Explanation. Here are some explanations for each of those steps: Equation - equations represent the models and frameworks for our research. They serve as a link between data and research ideas or designs. Estimation - estimation is the link between equations (models) and the data used for our research. They are the algorithms used to compute the parameters of our models. Evaluation - errors are used to evaluate the fit between models and data. These metrics evaluate the performance of our estimation methods and the produced models. Execution or explanation ‚Äì the explanation is the link between equations (models) and our intended research purposes. How we explain our results depends on our research purposes and also on the subject we are studying. Execution is the step that takes the created model for production, which is then utilized for decision making. ',
#  'Our RM4E workflow processes through the 4Es, standing for Equation, Estimation, Evaluation, Execution/Explanation. These four components may be combined together to guide different types of data analysis projects ',
#  'Our RM4E workflow processes through the 4Es, standing for Equation, Estimation, Evaluation, Execution/Explanation. These four components may be combined together to guide different types of data analysis projects ',
#  'Our RM4E workflow processes through the 4Es, standing for Equation, Estimation, Evaluation, Execution/Explanation. These four components may be combined together to guide different types of data analysis projects ',
#  'Please visit our website to learn more about RM4E workflow, link: https://grmds.org/node/399',
#  'Please visit our website to learn more about RM4E workflow, link: https://grmds.org/node/399',
#  'ResearchMap is based on the RM4Es idea, we can build up research flow, which is a collection of steps or actions needed to be done to reach the goal of a research project. ',
#  'ResearchMap is based on the RM4Es idea, we can build up research flow, which is a collection of steps or actions needed to be done to reach the goal of a research project. ',
#  'ResearchMap is based on the RM4Es idea, we can build up research flow, which is a collection of steps or actions needed to be done to reach the goal of a research project. ',
#  'ResearchMap is based on the RM4Es idea, we can build up research flow, which is a collection of steps or actions needed to be done to reach the goal of a research project. ',
#  'To learn more, please visit our website: https://grmds.org/researchmap',
#  'To learn more, please visit our website: https://grmds.org/researchmap',
#  'Our ResearchMap can be used to handle statistical strategies. Past experiments and extensive research demonstrates that when guided by a set of statistical strategies, junior researchers can perform better than if they were in a situation where no strategy guidance was available.',
#  'Our ResearchMap can be used to handle statistical strategies. Past experiments and extensive research demonstrates that when guided by a set of statistical strategies, junior researchers can perform better than if they were in a situation where no strategy guidance was available.',
#  'Our ResearchMap can be used to handle statistical strategies. Past experiments and extensive research demonstrates that when guided by a set of statistical strategies, junior researchers can perform better than if they were in a situation where no strategy guidance was available.',
#  'Our ResearchMap is for researchers who wants to deal with equivalent model issues with the help of the availablity of strategy guidance.',
#  'Our ResearchMap is for researchers who wants to deal with equivalent model issues with the help of the availablity of strategy guidance.',
#  'Our GRMDS ideal ecosystem consists of at least three elements: data portal, computing platform, and the data scientist community.',
#  'Our GRMDS ideal ecosystem consists of at least three elements: data portal, computing platform, and the data scientist community.',
#  'Our GRMDS ideal ecosystem consists of at least three elements: data portal, computing platform, and the data scientist community.',
#  'Our GRMDS ideal ecosystem consists of at least three elements: data portal, computing platform, and the data scientist community.',
#  'Our GRMDS ideal ecosystem consists of at least three elements: data portal, computing platform, and the data scientist community.',
#  'Our GRMDS ideal ecosystem consists of at least three elements: data portal, computing platform, and the data scientist community.',
#  'Our GRMDS ideal ecosystem consists of at least three elements: data portal, computing platform, and the data scientist community.',
#  'Our RMDS is an ecosystem service that empowers you get access to data science professionals and businesses worldwide to achieve successful, data-driven results. You can get connect with more than 40,000 datascientist worldwide!',
#  'Our RMDS is an ecosystem service that empowers you get access to data science professionals and businesses worldwide to achieve successful, data-driven results. You can get connect with more than 40,000 datascientist worldwide!',
#  'Our RMDS is an ecosystem service that empowers you get access to data science professionals and businesses worldwide to achieve successful, data-driven results. You can get connect with more than 40,000 datascientist worldwide!',
#  'Our RMDS is an ecosystem is designed to serve  data science professionals and businesses worldwide.',
#  'Our RMDS is an ecosystem is designed to serve  data science professionals and businesses worldwide.',
#  'To learn more, please visit our website: https://www.ecosystems.biz/',
#  'To learn more, please visit our website: https://www.ecosystems.biz/',
#  'In this course, you will learn about the RM4E analytical workflow, which guides the problem-solving process. We will not only teach you fundamental knowledge and skills but we will also take a look at how they are applied by professionals to build real end-to-end data science solutions.',
#  'In this course, you will learn about the RM4E analytical workflow, which guides the problem-solving process. We will not only teach you fundamental knowledge and skills but we will also take a look at how they are applied by professionals to build real end-to-end data science solutions.',
#  'In this course, you will learn about the RM4E analytical workflow, which guides the problem solving process. You will also encounter various cases where you will learn how different approaches may be adopted to solve industry problems.',
#  'In this course, you will learn about the RM4E analytical workflow, which guides the problem solving process. You will also encounter various cases where you will learn how different approaches may be adopted to solve industry problems.',
#  'In this course, you will learn about the RM4E analytical workflow, which guides the problem solving process. You will also encounter various cases where you will learn how different approaches may be adopted to solve industry problems.',
#  'Beginners who want to have a comprehensive understanding of the data science industry and data science analysis, or professionals who are interested in research workflows to increase the reproducibility of data science projects should take this course. ',
#  'Beginners who want to have a comprehensive understanding of the data science industry and data science analysis, or professionals who are interested in research workflows to increase the reproducibility of data science projects should take this course. ',
#  'You can find about the course at the website link: https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai',
#  'You can find about the course at the website link: https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai',
#  "This course's price is $39. You can find out more information at https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai",
#  "This course's price is $39. You can find out more information at https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai",
#  "This course's price is $39. You can find out more information at https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai",
#  'This course is 6 weeks long.Beginners who want to have a comprehensive understanding of the data science industry and data science analysis, or professionals who are interested in research workflows to increase the reproducibility of data science projects should take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai',
#  'This course is 6 weeks long.Beginners who want to have a comprehensive understanding of the data science industry and data science analysis, or professionals who are interested in research workflows to increase the reproducibility of data science projects should take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai',
#  'This course is 6 weeks long.Beginners who want to have a comprehensive understanding of the data science industry and data science analysis, or professionals who are interested in research workflows to increase the reproducibility of data science projects should take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai',
#  'This course is 6 weeks long.Beginners who want to have a comprehensive understanding of the data science industry and data science analysis, or professionals who are interested in research workflows to increase the reproducibility of data science projects should take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai',
#  'This practical 5-lesson training is suitable for those interested in applying data science to solve business problems. You will not only pick up fundamental knowledge and skills but you will also have an idea about how they are applied by professionals to build real end-to-end data science solutions.',
#  'This practical 5-lesson training is suitable for those interested in applying data science to solve business problems. You will not only pick up fundamental knowledge and skills but you will also have an idea about how they are applied by professionals to build real end-to-end data science solutions.',
#  'In this course, we will introduce the RM4E analytical workflow, which guides the problem-solving process and ensures the reproducibility. After taking this course, you will learn how each step may be adopted to solve real-world problems. ',
#  'In this course, we will introduce the RM4E analytical workflow, which guides the problem-solving process and ensures the reproducibility. After taking this course, you will learn how each step may be adopted to solve real-world problems. ',
#  'In this course, we will introduce the RM4E analytical workflow, which guides the problem-solving process and ensures the reproducibility. After taking this course, you will learn how each step may be adopted to solve real-world problems. ',
#  'Anyone who is interested in Data Science can take this course!',
#  'Anyone who is interested in Data Science can take this course!',
#  'You can find out more information at the course website link: https://learn.grmds.org/local/staticpage/view.php?page=TurningBusinessProblemsintoDataScienceProblem',
#  'You can find out more information at the course website link: https://learn.grmds.org/local/staticpage/view.php?page=TurningBusinessProblemsintoDataScienceProblem',
#  "This course's price is $0 (yes it's free!)",
#  "This course's price is $0 (yes it's free!)",
#  'This course is 5 weeks long. Anyone who is interested in Data Science can take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=TurningBusinessProblemsintoDataScienceProblem',
#  'This course is 5 weeks long. Anyone who is interested in Data Science can take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=TurningBusinessProblemsintoDataScienceProblem',
#  'This course is 5 weeks long. Anyone who is interested in Data Science can take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=TurningBusinessProblemsintoDataScienceProblem',
#  'This course is 5 weeks long. Anyone who is interested in Data Science can take this course. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=TurningBusinessProblemsintoDataScienceProblem',
#  'This six-week course provides a comprehensive and solid understanding of blockchain and crypto economics. Topics including smart contracts, cryptocurrencies, and blockchain governance will be elaborated on via case studies using Bitcoin, Etherum, and DFINITY as examples. We will also look at how blockchain is empowering decentralized finance applications.',
#  'This six-week course provides a comprehensive and solid understanding of blockchain and crypto economics. Topics including smart contracts, cryptocurrencies, and blockchain governance will be elaborated on via case studies using Bitcoin, Etherum, and DFINITY as examples. We will also look at how blockchain is empowering decentralized finance applications.',
#  'This course equips participants to thrive within the global paradigm shift for data-driven results and research across many industries globally. It will empower them through both artificial intelligence and business strategy initiatives. Learners will practice a data-driven methodology and academia/industry collaborative approach to answer research questions at the frontier of Fintech.',
#  'This course equips participants to thrive within the global paradigm shift for data-driven results and research across many industries globally. It will empower them through both artificial intelligence and business strategy initiatives. Learners will practice a data-driven methodology and academia/industry collaborative approach to answer research questions at the frontier of Fintech.',
#  'This course equips participants to thrive within the global paradigm shift for data-driven results and research across many industries globally. It will empower them through both artificial intelligence and business strategy initiatives. Learners will practice a data-driven methodology and academia/industry collaborative approach to answer research questions at the frontier of Fintech.',
#  'The course is open to a diverse audience interested in the Frontier of Fintech and AI, including but not limited to: researchers in academia interested in Fintech and/or the application of their research in data science workflows, or economists, data scientists, data engineers interested in research questions at the Frontier of Fintech and AI who possess the ambition to develop a systematic way of conducting research and technology transfer independently.',
#  'The course is open to a diverse audience interested in the Frontier of Fintech and AI, including but not limited to: researchers in academia interested in Fintech and/or the application of their research in data science workflows, or economists, data scientists, data engineers interested in research questions at the Frontier of Fintech and AI who possess the ambition to develop a systematic way of conducting research and technology transfer independently.',
#  'You can find more information at the course website here: https://learn.grmds.org/local/staticpage/view.php?page=FinancialTechnologyCryptocurrencyAI',
#  'You can find more information at the course website here: https://learn.grmds.org/local/staticpage/view.php?page=FinancialTechnologyCryptocurrencyAI',
#  "This course's price is $39. You can find out more information at https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai",
#  "This course's price is $39. You can find out more information at https://learn.grmds.org/local/staticpage/view.php?page=bigdataandai",
#  'This course is 6 weeks long. The course is open to a diverse audience interested in the Frontier of Fintech and AI, including but not limited to: researchers in academia interested in Fintech and/or the application of their research in data science workflows, or economists, data scientists, data engineers interested in research questions at the Frontier of Fintech and AI who possess the ambition to develop a systematic way of conducting research and technology transfer independently. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=FinancialTechnologyCryptocurrencyAI',
#  'This course is 6 weeks long. The course is open to a diverse audience interested in the Frontier of Fintech and AI, including but not limited to: researchers in academia interested in Fintech and/or the application of their research in data science workflows, or economists, data scientists, data engineers interested in research questions at the Frontier of Fintech and AI who possess the ambition to develop a systematic way of conducting research and technology transfer independently. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=FinancialTechnologyCryptocurrencyAI',
#  'This course is 6 weeks long. The course is open to a diverse audience interested in the Frontier of Fintech and AI, including but not limited to: researchers in academia interested in Fintech and/or the application of their research in data science workflows, or economists, data scientists, data engineers interested in research questions at the Frontier of Fintech and AI who possess the ambition to develop a systematic way of conducting research and technology transfer independently. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=FinancialTechnologyCryptocurrencyAI',
#  'This course is 6 weeks long. The course is open to a diverse audience interested in the Frontier of Fintech and AI, including but not limited to: researchers in academia interested in Fintech and/or the application of their research in data science workflows, or economists, data scientists, data engineers interested in research questions at the Frontier of Fintech and AI who possess the ambition to develop a systematic way of conducting research and technology transfer independently. This course website link is https://learn.grmds.org/local/staticpage/view.php?page=FinancialTechnologyCryptocurrencyAI',
#  'Detection and analysis systems are ubiquitously used across all domains of life (education, work, leisure) to access resources and opportunities. This six-week program covers the fundamental concepts in AI ethics, how the recognition and analysis systems manifest bias, how they are used in different settings and what the consequences are.',
#  'Detection and analysis systems are ubiquitously used across all domains of life (education, work, leisure) to access resources and opportunities. This six-week program covers the fundamental concepts in AI ethics, how the recognition and analysis systems manifest bias, how they are used in different settings and what the consequences are.',
#  'Throughout this program, learners will gain a strong understanding of these systems, and the consequences of what they develop, use and implement in their lives. They will also gain an in-depth and comprehensive analysis of AI Bias as the program starts with concepts and then moves to real world applications of these concepts. ',
#  'Throughout this program, learners will gain a strong understanding of these systems, and the consequences of what they develop, use and implement in their lives. They will also gain an in-depth and comprehensive analysis of AI Bias as the program starts with concepts and then moves to real world applications of these concepts. ',
#  'Throughout this program, learners will gain a strong understanding of these systems, and the consequences of what they develop, use and implement in their lives. They will also gain an in-depth and comprehensive analysis of AI Bias as the program starts with concepts and then moves to real world applications of these concepts. ',
# ...
#  'NFTs have been applied to various fields, including science, technology, and art. With NFTs becoming more popular, RMDS Lab is announcing its next data science competition - Creating a NFT Value Dashboard to Summarize the Past and Predict the Future. Contestants will be challenged with collecting datasets to create a dashboard that assesses trends in the development of NFTs and forecast their future trajectory.',
#  'To learn more about Contestants in RMDS, please visit: https://grmds.org/comp/nft',
#  'To learn more about Contestants in RMDS, please visit: https://grmds.org/comp/nft',
#  'NFT Exchange is a system developed by RMDS that helps users to directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs',
#  'NFT Exchange is a system developed by RMDS that helps users to directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs',
#  'NFT Exchange is a system developed by RMDS that helps users to directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs',
#  'In NFT Exchange, Users can directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs ',
#  'In NFT Exchange, Users can directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs ',
#  'In NFT Exchange, Users can directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs ',
#  'In NFT Exchange, Users can directly interchange projects/workflows/data/source codes/reports, and then take them to rmdsNFT.com, or directly exchange IPs there via NFTs ',
#  'Users can confidently trade their assets with anonymous counterparts while avoiding any deception and risk of fraudulent activity. You can transform your digital files into digital assets at RMDS Marketplace to help you communicate. You can transform your digital files into digital assets at RMDS Marketplace to help you communicate.',
#  'Users can confidently trade their assets with anonymous counterparts while avoiding any deception and risk of fraudulent activity. You can transform your digital files into digital assets at RMDS Marketplace to help you communicate. You can transform your digital files into digital assets at RMDS Marketplace to help you communicate.',
#  'PLease check https://rmdsnft.com/ for further information.',
#  'PLease check https://rmdsnft.com/ for further information.',
#  'At RMDS, we offer a wide range of different positions for those who are passionate about Data Science. We have the Project/Program Management Intern to support the development of the campus ambassador program and data science team. Link: https://www.rmdslab.com/careers/ We also have the RMDS Project Impactor (PI) Program, which is designed to help those interested in Data Science and AI to develop their skills and prepare them for a successful career. The program offers a variety of roles and responsibilities that PI can undertake based on their skills, interests, and professional goals.',
#  'At RMDS, we offer a wide range of different positions for those who are passionate about Data Science. We have the Project/Program Management Intern to support the development of the campus ambassador program and data science team. Link: https://www.rmdslab.com/careers/ We also have the RMDS Project Impactor (PI) Program, which is designed to help those interested in Data Science and AI to develop their skills and prepare them for a successful career. The program offers a variety of roles and responsibilities that PI can undertake based on their skills, interests, and professional goals.',
#  'At RMDS, we offer a wide range of different positions for those who are passionate about Data Science. We have the Project/Program Management Intern to support the development of the campus ambassador program and data science team. Link: https://www.rmdslab.com/careers/ We also have the RMDS Project Impactor (PI) Program, which is designed to help those interested in Data Science and AI to develop their skills and prepare them for a successful career. The program offers a variety of roles and responsibilities that PI can undertake based on their skills, interests, and professional goals.',
#  'Please visit our wbesite to learn more, link: https://grmds.org/careers/pi-program',
#  'Impact score is a system that measures a data scientist’s practical impact in their field. Calculated using public records and platform user data, the impact score demonstrates an individual’s power or capacity to effect positive change in their field.',
#  'Impact score is a system that measures a data scientist’s practical impact in their field. Calculated using public records and platform user data, the impact score demonstrates an individual’s power or capacity to effect positive change in their field.',
#  'Impact score is a system that measures a data scientist’s practical impact in their field. Calculated using public records and platform user data, the impact score demonstrates an individual’s power or capacity to effect positive change in their field.',
#  'Impact score is break down into Project Quality, Project Management, Project Outcome, Perceived Capacity, and Perceived Participation. Impact score offers technical recruiters, Executives, Researchers, Academic institutions, and Data scientists a better view of their performance in data science industry',
#  'Impact score is break down into Project Quality, Project Management, Project Outcome, Perceived Capacity, and Perceived Participation. Impact score offers technical recruiters, Executives, Researchers, Academic institutions, and Data scientists a better view of their performance in data science industry',
#  'Technical recruiters, Executives, Researchers, Academic institutions, and Data scientists tend to use impact score, which help them to quantify their performance in data science industry.',
#  'Technical recruiters, Executives, Researchers, Academic institutions, and Data scientists tend to use impact score, which help them to quantify their performance in data science industry.',
#  'For more information, check out this blog at https://medium.com/rmds-lab/measuring-your-impact-in-the-data-science-community-how-impact-score-can-show-your-worth-33e9e134a138.',
#  'For more information, check out this blog at https://medium.com/rmds-lab/measuring-your-impact-in-the-data-science-community-how-impact-score-can-show-your-worth-33e9e134a138.',
#  'RMDS wants to recommend RMDS user to other RMDS users based on user similarity. RMDS Recommendation system would collect user data from the database and calculate out similarity scores for each pair of users, and recommend users to users who have high similarity scores with them.',
#  'RMDS wants to recommend RMDS user to other RMDS users based on user similarity. RMDS Recommendation system would collect user data from the database and calculate out similarity scores for each pair of users, and recommend users to users who have high similarity scores with them.',
#  'RMDS wants to recommend RMDS user to other RMDS users based on user similarity. RMDS Recommendation system would collect user data from the database and calculate out similarity scores for each pair of users, and recommend users to users who have high similarity scores with them.',
#  'RMDS wants to recommend RMDS user to other RMDS users based on user similarity. RMDS Recommendation system would collect user data from the database and calculate out similarity scores for each pair of users, and recommend users to users who have high similarity scores with them.',
#  'This is one of its open-source projects, user recommender, which is deployed on the RMDS LAB. RMDS would collect user data from the database and calculate out similarity scores for each pair of users, and recommend users to users who have high similarity scores with them.',
#  'This is one of its open-source projects, user recommender, which is deployed on the RMDS LAB. RMDS would collect user data from the database and calculate out similarity scores for each pair of users, and recommend users to users who have high similarity scores with them.',
#  'Data scientists who value open sourse projects and are in charm of algorithms',
#  'Data scientists who value open sourse projects and are in charm of algorithms',
#  'RMDS Lab is aiming to make its work more public to let data scientists enjoy the charm in algorithms. This is one of its open-source projects, user recommender, which is deployed on the RMDS LAB',
#  'RMDS Lab is aiming to make its work more public to let data scientists enjoy the charm in algorithms. This is one of its open-source projects, user recommender, which is deployed on the RMDS LAB',
#  'RMDS Lab is aiming to make its work more public to let data scientists enjoy the charm in algorithms. This is one of its open-source projects, user recommender, which is deployed on the RMDS LAB',
#  'RMDS Lab is aiming to make its work more public to let data scientists enjoy the charm in algorithms. This is one of its open-source projects, user recommender, which is deployed on the RMDS LAB',
#  'You may check out at this github website to find out about more details about the codes and algorithms: https://github.com/GRMDS/User_Recommender',
#  'You may check out at this github website to find out about more details about the codes and algorithms: https://github.com/GRMDS/User_Recommender',
#  'One of the upskill program we have is the Project Impactor Upskill Program, in which you’ll complete capstone projects focused on real data science scenarios that you can show to future employers. Project-based mentorship will be provided for technical guidance to help students complete the projects. Each project is 6 weeks. Most students devote 5-10 hours a week to complete a project. ',
#  'One of the upskill program we have is the Project Impactor Upskill Program, in which you’ll complete capstone projects focused on real data science scenarios that you can show to future employers. Project-based mentorship will be provided for technical guidance to help students complete the projects. Each project is 6 weeks. Most students devote 5-10 hours a week to complete a project. ',
#  'One of the upskill program we have is the Project Impactor Upskill Program, in which you’ll complete capstone projects focused on real data science scenarios that you can show to future employers. Project-based mentorship will be provided for technical guidance to help students complete the projects. Each project is 6 weeks. Most students devote 5-10 hours a week to complete a project. ',
#  'One of the upskill program we have is the Project Impactor Upskill Program, in which you’ll complete capstone projects focused on real data science scenarios that you can show to future employers. Project-based mentorship will be provided for technical guidance to help students complete the projects. Each project is 6 weeks. Most students devote 5-10 hours a week to complete a project. ',
#  'College students who want to apply for master’s degrees in data science-related fields, new graduates who want to pursue career paths in data science-related fields , professionals who want to advance their careers or navigate a mid-career change, or even high school students who are interested in data science and want to apply for college can participate in our upskill program.',
#  'College students who want to apply for master’s degrees in data science-related fields, new graduates who want to pursue career paths in data science-related fields , professionals who want to advance their careers or navigate a mid-career change, or even high school students who are interested in data science and want to apply for college can participate in our upskill program.',
#  'Our upskill program could help you either apply for master’s degrees in data science-related fields, pursue career paths in data science-related fields,  advance careers, or navigate a mid-career change.',
#  'Our upskill program could help you either apply for master’s degrees in data science-related fields, pursue career paths in data science-related fields,  advance careers, or navigate a mid-career change.',
#  'Our upskill program could help you either apply for master’s degrees in data science-related fields, pursue career paths in data science-related fields,  advance careers, or navigate a mid-career change.',
#  'Find out more at the link: https://grmds.org/projectimpactor-upskillprogram',
#  'Find out more at the link: https://grmds.org/projectimpactor-upskillprogram',
#  'At RMDS, we offer a wide range of Practical Data Science Training through onsite / online courses, webinars, programs, Bootcamps, Workshops, and hands-on projects. ',
#  'At RMDS, we offer a wide range of Practical Data Science Training through onsite / online courses, webinars, programs, Bootcamps, Workshops, and hands-on projects. ',
#  'At RMDS, we offer a wide range of Practical Data Science Training through onsite / online courses, webinars, programs, Bootcamps, Workshops, and hands-on projects. ',
#  'At RMDS, we offer a wide range of Practical Data Science Training through onsite / online courses, webinars, programs, Bootcamps, Workshops, and hands-on projects. ',
#  'Our Practical Data Science Training offer a wide range of Practical Data Science Training through onsite / online courses, webinars, programs, Bootcamps, Workshops, and hands-on projects.',
#  'Our Practical Data Science Training offer a wide range of Practical Data Science Training through onsite / online courses, webinars, programs, Bootcamps, Workshops, and hands-on projects.',
#  'Our Practical Data Science Training offer a wide range of Practical Data Science Training through onsite / online courses, webinars, programs, Bootcamps, Workshops, and hands-on projects.',
#  'If you are in need of Practical Data Science training, our onsite/online courses would be the right place you should check out. Please check out our websites for more details: https://www.rmdslab.com/products/training/',
#  'If you are in need of Practical Data Science training, our onsite/online courses would be the right place you should check out. Please check out our websites for more details: https://www.rmdslab.com/products/training/',
#  'Please check out our websites for more details: https://www.rmdslab.com/products/training/',
#  'Please check out our websites for more details: https://www.rmdslab.com/products/training/',
#  'Prior to the annually IMDATA conference, we offer special training for anyone in need to better prepare for the conference. ',
#  'Prior to the annually IMDATA conference, we offer special training for anyone in need to better prepare for the conference. ',
#  'Prior to the annually IMDATA conference, we offer special training for anyone in need to better prepare for the conference. ',
#  'The Pre-conference is for anyone in need to better prepare for the IMDATA conference. ',
#  'The Pre-conference is for anyone in need to better prepare for the IMDATA conference. ',
#  'The Pre-conferencel training offers you a better position in the IMDATA conference.',
#  'The Pre-conferencel training offers you a better position in the IMDATA conference.',
#  'The Pre-conferencel training offers you a better position in the IMDATA conference.',
#  'Please check our websites for more details: https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/',
#  'Please check our websites for more details: https://www.rmdslab.com/im-data-2021-speakers-pre-conference-training/']

# %%
question_text
# Out:
# ['What is RMDS Lab?',
#  'What is RMDS?',
#  'RMDS Lab is what?',
#  'who are you?',
#  'RMDS Lab?',
#  'what is the mission of RMDS Lab?',
#  'what is the goal of RMDS Lab?',
#  'why RMDS Lab?',
#  'what does RMDS Lab mean?',
#  'what does RMDS do?',
#  'why choose RMDS?',
#  'what can I benefit from RMDS?',
#  'where can I learn more about RMDS?',
#  'where to find RMDS?',
#  'what services do you have?',
#  'what services does RMDS Lab have?',
#  'what does RMDS Lab do?',
#  'why choose RMDS lab?',
#  'why is RMDS Lab useful?',
#  'what services can RMDS Lab provide me?',
#  'why is RMDS Lab legit?',
#  'what services/products do RMDS Lab offer?',
#  "where can I learn more about RMDS's services and products?",
#  "where to find RMDS's services and products?",
#  'what courses do you have?',
#  'How can you help me?',
#  'do you have any courses?',
#  'Courses?',
#  'do you have any classes?',
#  'what courses can I take?',
#  'how can I improve my data science skills?',
#  'what kind of skills I have to learn?',
#  'what can I learn from RMDS courses?',
#  'what can I benefit from RMDS courses?',
#  'what kind of training do you have?',
#  'what kind of training does RMDS Lab have?',
#  'why learn with RMDS?',
#  "why is RMDS's courses credible?",
#  "why trust RMDS's courses?",
#  'who should study RMDS courses?',
#  'RMDS courses are for whom?',
#  "where can I learn more about RMDS's courses?",
#  "where should I go to find out RMDS's courses?",
#  'what kind of event do you have?',
#  'what kind of event does RMDS Lab have?',
#  'what kind of competition do you have?',
#  'what kind of competition does RMDS Lab have?',
#  'what kind of activity do you have?',
#  'what kind of activity does RMDS Lab have?',
#  'where are the events?',
#  'where do the events take place?',
#  'where do RMDS host the events?',
#  'where do I find the events?',
#  'what are the events about?',
#  'what people attend the events?',
#  'why attend RMDS events?',
#  'what can I benefit from RMDS events?',
#  'how frequently are the events?',
#  'when are the events held?',
#  'where can I learn more about RMDS events?',
#  'where to find out RMDS events?',
#  'what is project portal?',
#  'project portal?',
#  'how to use project portal?',
#  'what does project portal mean?',
#  'how does project portal help me?',
#  'what can I benefit from project portal?',
#  'where can I learn more about project portal?',
#  'where can I find out project portal?',
#  'what is Data Science Portfolio?',
#  'data science portfolio?',
#  'what does Data Science Portfolio mean?',
#  'how to use Data Science Portfolio?',
#  'how does Data Science Portfolio help me?',
#  'what can I benefit from Data Science Portfolio?',
#  'what is RMDS Exchange?',
#  'RMDS Exchange?',
#  'what does RMDS Exchange mean?',
#  'how to use RMDS Exchange?',
#  'how does RMDS Exchange help me?',
#  'what can I benefit from RMDS Exchange?',
#  'where can I learn more abour RMDS Exchange?',
#  'where should I go to find out RMDS Exchange?',
#  'what is NFT  Market?',
#  'NFT Market?',
#  'how to use NFT Market?',
#  'what does NFT Market mean?',
#  'how does NFT Market help me?',
#  'what can I benefit from NFT Market?',
#  'why is NFT Market useful?',
#  'where can I learn more about NFT Market',
#  'where should I go to find out NFT Market?',
#  'what is RM4Es?',
#  'what is RM4E workflow?',
#  'RM4E workflow?',
#  'RM4Es?',
#  'what does RM4Es mean?',
#  'what does RM4E workflow mean?',
#  'how does RM4E workflow help me?',
#  'what can I benefit from RM4E workflow?',
#  'why is RM4E workflow useful?',
#  'where can I learn more about RM4E workflow?',
#  'where to find information about RM4E workflow?',
#  'what is ResearchMap?',
#  'ResearchMap?',
#  'how to use ResearchMap?',
#  'what does ResearchMap mean?',
#  'where can I learn more aboout ResearchMap?',
#  'where should I go to find out ResearchMap?',
#  'how does ResearchMap help me?',
#  'what can I benefit from ResearchMap?',
#  'why ResearchMap is useful?',
#  'who should use the ResearchMap?',
#  'Research Map is for Whom?',
#  'what is GRMDS Ecosystem?',
#  'what does GRMDS Ecosystem mean?',
#  'GRMDS Ecosystem?',
#  'what is ecosystem approach?',
#  'ecosystem approach?',
#  'how to use ecosystem approach?',
#  'what does ecosystem approach mean?',
#  'what can I do on GRMDS Ecosystem?',
#  'how can GRMDS idel ecosystem help me?',
#  'why should I use GRMDS Ecosystem?',
#  'who should visit the GRMDS ideal ecosystem?',
#  'GRMDS Ecosystem is for whom?',
#  'where can I learn more about ecosystem?',
#  'where can I get access to ecosystem?',
#  'what is Big Data and AI to Improve Competency and Employability course?',
#  'Big Data and AI to Improve Competency and Employability course?',
#  'what can I learn from Big Data and AI to Improve Competency and Employability course?',
#  'how does Big Data and AI to Improve Competency and Employability course help me?',
#  'why should I learn Big Data and AI to Improve Competency and Employability course?',
#  'who should take Big Data and AI to Improve Competency and Employability course?',
#  'Big Data and AI to Improve Competency and Employability course is for whom?',
#  'where should I find Big Data and AI to Improve Competency and Employability course?',
#  'where should I go to participate in Big Data and AI to Improve Competency and Employability course?',
#  'how much money do I need to pay for Big Data and AI to Improve Competency and Employability course?',
#  'how much is Big Data and AI to Improve Competency and Employability course?',
#  'how much does it cost for Big Data and AI to Improve Competency and Employability course?',
#  'how long does Big Data and AI to Improve Competency and Employability course take?',
#  'how many weeks does Big Data and AI to Improve Competency and Employability course take?',
#  'how difficult is Big Data and AI to Improve Competency and Employability course?',
#  'what is the difficulty level of the Big Data and AI to Improve Competency and Employability course?',
#  'what is Turning Business Problems into Data Science Problems course?',
#  'Turning Business Problems into Data Science Problem course?',
#  'what can I learn from Turning Business Problems into Data Science Problems course?',
#  'how does Turning Business Problems into Data Science Problems course help me?',
#  'why should I learn Turning Business Problems into Data Science Problem course?',
#  'who should take Turning Business Problems into Data Science Problems course?',
#  'Turning Business Problems into Data Science Problem course is for whom?',
#  'where should I find Turning Business Problems into Data Science Problem course?',
#  'where should I go to participate in Turning Business Problems into Data Science Problem course?',
#  'how much is Turning Business Problems into Data Science Problems course?',
#  'how much money do I need to pay for Turning Business Problems into Data Science Problems course?',
#  'how long does Turning Business Problems into Data Science Problems course take?',
#  'how many weeks does Turning Business Problems into Data Science Problems course take?',
#  'how difficult is Turning Business Problems into Data Science Problems course?',
#  'what is the difficulty level of the Turning Business Problems into Data Science Problems course?',
#  'what is Financial Technology, Cryptocurrency & AI course?',
#  'Financial Technology, Cryptocurrency & AI course?',
#  'what can I learn from Financial Technology, Cryptocurrency & AI course?',
#  'how does Financial Technology, Cryptocurrency & AI course help me?',
#  'why should I learn Financial Technology, Cryptocurrency & AI course?',
#  'who should take Financial Technology, Cryptocurrency & AI course?',
#  'Financial Technology, Cryptocurrency & AI course? is for whom?',
#  'where should I find Financial Technology, Cryptocurrency & AI course?',
#  'where should I go to participate in Financial Technology, Cryptocurrency & AI course?',
#  'how much is Financial Technology, Cryptocurrency & AI course?',
#  'how much money do I need to pay for Financial Technology, Cryptocurrency & AI course?',
#  'how long does Financial Technology, Cryptocurrency & AI take?',
#  'how many week does Financial Technology, Cryptocurrency & AI course take?',
#  'how difficult is Financial Technology, Cryptocurrency & AI course?',
#  'what is the difficulty level of the Financial Technology, Cryptocurrency & AI course?',
#  'what is AI Bias & Surveillance: Recognition, Analysis, and Prediction course?',
#  'AI Bias & Surveilance: Recognition, Analysis, and Prediction course?',
#  'what can I learn from AI Bias & Surveillance: Recognition, Analysis, and Prediction course?',
#  'how does AI Bias & Surveilance: Recognition, Analysis, and Prediction course help me?',
#  'why should I learn AI Bias & Surveilance: Recognition, Analysis, and Prediction course?',
#  'who should take AI Bias & Surveillance: Recognition, Analysis, and Precidtion course?',
#  'AI Bias & Surveillance: Recognition, Analysis, and Precidtion course is for whom?',
#  'where should I find AI Bias & Surveilance: Recognition, Analysis, and Prediction course?',
#  'where should I go to participate in AI Bias & Surveilance: Recognition, Analysis, and Prediction course?',
#  'how much is AI Bias & Surveillance: Recognition, Analysis, and Prediction?',
#  'how much money do I need to pay for AI Bias & Surveillance: Recognition, Analysis, and Prediction course?',
#  'how long does AI Bias & Surveillance: Recognition, Analysis, and Prediction take?',
#  'how many weeks does AI Bias & Surveillance: Recognition, Analysis, and Prediction course take?',
#  'how difficult is AI Bias & Surveillance: Recognition, Analysis, and Precidtion course?',
#  'what is the difficulty level of the AI Bias & Surveillance: Recognition, Analysis, and Precidtion course?',
#  'what is Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'how does Monthly Data Science Training Webinars: Workflow-based Data Analysis course help me?',
#  'what can I learn from Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'why should I learn Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'who should take Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'Monthly Data Science Training Webinars: Workflow-based Data Analysis course is for whom?',
#  'where should I find Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'where should I go to participate in Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'how much is Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'how much money do I need to pay for Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'how long does Monthly Data Science Training Webinars: Workflow-based Data Analysis take?',
#  'how many weeks does Monthly Data Science Training Webinars: Workflow-based Data Analysis take?',
#  'how difficult is Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'what is the difficulty level of the Monthly Data Science Training Webinars: Workflow-based Data Analysis course?',
#  'what is CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'how does CDI Training Webinars on Research Data: Sources, Tools, and Applications course help me?',
#  'what can I learn from CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'why should I learn CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'who should take CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'CDI Training Webinars on Research Data: Sources, Tools, and Applications course is for whom?',
#  'where should I find CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'where should I go to participate in CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'how much is CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'how much money do I need to pay for CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'how long does CDI Training Webinars on Research Data: Sources, Tools, and Applications take?',
#  'how many weeks does CDI Training Webinars on Research Data: Sources, Tools, and Applications take?',
#  'how difficult is CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'what is the difficulty level of the CDI Training Webinars on Research Data: Sources, Tools, and Applications course?',
#  'what is AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'what can I learn from AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'how does AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course help me?',
#  'why should I learn AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'who should take AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course is for whom?',
#  'where should I find AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'where should I go to participate in AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'how much is AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'how much money do I need to pay for AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'how long does AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems take?',
#  'how many weeks does AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems take?',
#  'how difficult is AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'what is the difficulty level of the AI & Ethics: Bias, Diversity and Ethical Decision Making with AI Systems course?',
#  'what is RMDS Lab Webinar Series course?',
#  'RMDS Lab Webinar Series course?',
#  'what can I learn from RMDS Lab Webinar Series course?',
#  'how does RMDS Lab Webinar Series course help me?',
#  'why should I learn RMDS Lab Webinar Series course?',
#  'who should take RMDS Lab Webinar Series course?',
#  'RMDS Lab Webinar Series course is for whom?',
#  'where should I find RMDS Lab Webinar Series course?',
#  'where should I go to participate in RMDS Lab Webinar Series course?',
#  'how much is RMDS Lab Webinar Series course?',
#  'how much money do I need to pay for RMDS Lab Webinar Series course?',
#  'how long does RMDS Lab Webinar Series take?',
#  'how many weeks does RMDS Lab Webinar Series take?',
#  'how difficult is RMDS Lab Webinar Series course?',
#  'what is the difficulty level of the RMDS Lab Webinar Series course?',
#  'what is Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'what can I learn from Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'how can Tackling COVID-19: Literature Review of Covid-19 Research course help me?',
#  'why should I learn Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'who should take Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'Tackling COVID-19: Literature Review of Covid-19 Research course is for whom?',
#  'where should I find Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'where should I go to participate in Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'how much is Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'how much money do I need to pay for Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'how long does Tackling COVID-19: Literature Review of Covid-19 Research course take?',
#  'how many weeks does Tackling COVID-19: Literature Review of Covid-19 Research course take?',
#  'how difficult is Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'what is the difficulty level of the Tackling COVID-19: Literature Review of Covid-19 Research course?',
#  'what is Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'what can I learn from Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'how can COVID-19: Models and Methodologies of Covid-19 Data Collection course help me?',
#  'why should I learn COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'who should take COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'COVID-19: Models and Methodologies of Covid-19 Data Collection course is for whom?',
#  'where should I find COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'where should I go to participate in COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'how much is Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'how much money do I need to pay for Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'how long does Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course take?',
#  'how many weeks does Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course take?',
#  'how difficult is Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'what is the difficulty level of Tackling COVID-19: Models and Methodologies of Covid-19 Data Collection course?',
#  'what is Facebook Ad Analysis Using Python course?',
#  'Facebook Ad Analysis Using Python course?',
#  'what can I learn from Facebook Ad Analysis Using Python course?',
#  'how can Facebook Ad Analysis Using Python course help me?',
#  'why should I learn Facebook Ad Analysis Using Python course?',
#  'who should take Facebook Ad Analysis Using Python course?',
#  'Facebook Ad Analysis Using Python course is for whom?',
#  'where should I find Facebook Ad Analysis Using Python course?',
#  'where should I go to participate in Facebook Ad Analysis Using Python course?',
#  'how much is Facebook Ad Analysis Using Python course?',
#  'how much money do I need to pay for Facebook Ad Analysis Using Python course?',
#  'how long does Facebook Ad Analysis Using Python take?',
#  'how many weeks does Facebook Ad Analysis Using Python take?',
#  'how difficult is Facebook Ad Analysis Using Python course?',
#  'what is the difficulty level of Facebook Ad Analysis Using Python course?',
#  'what is KNIME Analytics Platform for Data Scientists: Basics course?',
#  'KNIME Analytics Platform for Data Scientists: Basics course?',
#  'what can I learn fromKNIME Analytics Platform for Data Scientists: Basics course?',
#  'how can KNIME Analytics Platform for Data Scientists: Basics course help me/',
#  'why should I learn KNIME Analytics Platform for Data Scientists: Basics course?',
#  'who should take KNIME Analytics Platform for Data Scientists: Basics course?',
#  'KNIME Analytics Platform for Data Scientists: Basics course is for whom?',
#  'where should I find  KNIME Analytics Platform for Data Scientists: Basics course?',
#  'where should I go to participate in KNIME Analytics Platform for Data Scientists: Basics course?',
#  'how much is KNIME Analytics Platform for Data Scientists: Basics course?',
#  'how much money do I need to pay for KNIME Analytics Platform for Data Scientists: Basics course?',
#  'how long does KNIME Analytics Platform for Data Scientists: Basics course take?',
#  'how many weeks does KNIME Analytics Platform for Data Scientists: Basics course take?',
#  'how difficult is KNIME Analytics Platform for Data Scientists: Basics course?',
#  'what is the difficulty level of KNIME Analytics Platform for Data Scientists: Basics course?',
#  'what is KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'what can I learn from KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'how can KNIME Analytics Platform for Data Scientists: Advanced course help me?',
#  'why should I learn KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'who should take KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'KNIME Analytics Platform for Data Scientists: Advanced course is for whom?',
#  'where should I find KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'where should I go to participate in KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'how much is KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'how much money do I need to pay for KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'how long does KNIME Analytics Platform for Data Scientists: Advanceds course take?',
#  'how many weeks does KNIME Analytics Platform for Data Scientists: Advanced course take?',
#  'how difficult is KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'what is the difficulty level KNIME Analytics Platform for Data Scientists: Advanced course?',
#  'what is Everything About Chatbots: A Hands on Journey course?',
#  'Everything About Chatbots: A Hands on Journey course?',
#  'what can I learn from Everything About Chatbots: A Hands on Journey course?',
#  'how can Everything About Chatbots: A Hands on Journey course help me?',
#  'why should I learn Everything About Chatbots: A Hands on Journey course?',
#  'who should take Everything About Chatbots: A Hands on Journey course?',
#  'Everything About Chatbots: A Hands on Journey course is for whom?',
#  'where should I find Everything About Chatbots: A Hands on Journey course?',
#  'where should I go to participate in Everything About Chatbots: A Hands on Journey course? ',
#  'how much is Everything About Chatbots: A Hands on Journey course?',
#  'how much money do I need to pay for Everything About Chatbots: A Hands on Journey course?',
#  'how long does Everything About Chatbots: A Hands on Journey course take?',
#  'how many weeks does Everything About Chatbots: A Hands on Journey course take?',
#  'how difficult is Everything About Chatbots: A Hands on Journey course?',
#  'what is the difficulty level of Everything About Chatbots: A Hands on Journey course?',
#  'what is Creation of Specialized AI Assistant for Healthcare Industry?',
#  'Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'what can I learn from Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'how can Creation of Specialized AI Assistant for Healthcare Industry course help me?',
#  'why should I learn Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'who should take Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'Creation of Specialized AI Assistant for Healthcare Industry course is for whom?',
#  'where should I find the Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'where should I go to participate in the Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'how much is Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'how long does Creation of Specialized AI Assistant for Healthcare Industry course take?',
#  'how many weeks does Creation of Specialized AI Assistant for Healthcare Industry course take?',
#  'how difficult is Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'what is the difficulty level of Creation of Specialized AI Assistant for Healthcare Industry course?',
#  'what is Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'what can I learn from Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'how can Applying Machine Learning to Create a Web-based Realtime Forecasting System course help me?',
#  'why should I learn Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'who should take Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'Applying Machine Learning to Create a Web-based Realtime Forecasting System course is for whom?',
#  'where should I find the Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'where should I go to participate in the Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'how much is Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'how much money do I need to pay for Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'how long does Applying Machine Learning to Create a Web-based Realtime Forecasting System course take?',
#  'how many weeks does Applying Machine Learning to Create a Web-based Realtime Forecasting System course take?',
#  'how difficult is Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'what is the difficulty level of Applying Machine Learning to Create a Web-based Realtime Forecasting System course?',
#  'what Artificial Intelligence course do you have?',
#  'what AI course do you have?',
#  'Do you have any Artificial Intelligence course?',
#  'Do you have any AI course?',
#  'where could I find course about AI?',
#  'where should I go to learn more about AI?',
#  "Thsi course's price is $39. ",
#  'what Machine Learning course do you have?',
#  'what ML course do you have?',
#  'Do you have any Machine Learning course?',
#  'Do you have any ML course?',
#  'where could I find course about Machine Learning?',
#  'where should I go to learn more about Machine Learning?',
#  'what Python course do you have?',
#  'Do you have any Python course?',
#  'where could I find course about Python?',
#  'wheres should I go to learn more about Python?',
#  'What is GRMDS?',
#  'GRMDS is what?',
#  'what does GRMDS mean?',
#  'GRMDS?',
#  'who should care about GRMDS?',
#  'GRMDS is build for whom?',
#  'why should I care abput GRMDS?',
#  'where can I learn more about GRMDS?',
#  'where to find out GRMDS?',
#  'what is IMDATA?',
#  'IMDATA?',
#  'what does IMDATA mean?',
#  'how can IMDATA help me?',
#  'what can I learn from IMDATA?',
#  'why should I care about IMDATA?',
#  'who should participate in IMDATA?',
#  'IMDATA is for whom?',
#  'how much is IMDATA?',
#  'how much does IMDATA cost?',
#  'how can I participate in IMDATA?',
#  'where can I find information about IMDATA?',
#  'where should I go to learn more about IMDATA?',
#  'when is the IMDATA?',
#  'what time is the IMDATA?',
#  'what is Quaterly Competition?',
#  'Quaterly Competition?',
#  'what does Quaterly Competition mean?',
#  'how can Quaterly Competition help me?',
#  'what can I learn from Quaterly Competition?',
#  'who should participate in Quaterly Competition?',
#  'Quaterly Competition is for whom?',
#  'When are Quaterly Competition held?',
#  'where can I find Quaterly Competition?',
#  'where can I learn more about Quaterly Competition?',
#  'when do the courses start?',
#  'when can I start the course?',
#  'can I take the course anytime?',
#  'Is the course online?',
#  'are the courses online?',
#  'Is the course offline?',
#  'are the courses offline?',
#  'where can I learn more about online courses?',
#  'where to find further informations about online courses?',
#  'what is NFT?',
#  'NFT is what?',
#  'NFT?',
#  'what does NFT mean?',
#  'how is NFT different?',
#  'why should I use NFT?',
#  'how can NFT Exchange help me?',
#  'where can I learn more about NFT?',
#  'where should I go to find out NFT Exchange?',
#  'what is NFT Exchange?',
#  'NFT Exchange?',
#  'what does NFT Exchange mean?',
#  'where can I excahnge NFT?',
#  'how can I sell a NFT?',
#  'how can I buy a NFT?',
#  'where can I interchange NFT?',
#  'why should I use NFT Exchange?',
#  'how can NFT Exchange help me?',
#  'where can I learn more about NFT Exchange?',
#  'where should I go to find out NFT Exchange?',
#  'what internship opportunities do you have?',
#  'internship opportunities?',
#  'what are internship opportunities like?',
#  'where can I learn more about intership opportunities?',
#  'what does impact score mean?',
#  'what is impact score?',
#  'impact score?',
#  'how does impact score help me?',
#  'what can i benefit from impact score?',
#  'who should use impact score?',
#  'impact score is for whom?',
#  'where can I learn more about impact score?',
#  'where to find impact score?',
#  'what is the recommendation system?',
#  'Recommendation system?',
#  'what recommendation system do you have?',
#  'what does recommendation system mean?',
#  'how does recommendation system help me?',
#  'what can I benefit from recommendation system?',
#  'who should use the recommendation system?',
#  'recommendation system is for whom?',
#  "what is RMDS's aim to build a Recommandation system?",
#  'why did RMDS build the Recommandation system?',
#  'why is RMDS running a Recommandation system ?',
#  'what is the purpose of having a Recommandation system?',
#  'where can I learn more about Recommandation system?',
#  'where to find out Recommandation system?',
#  'what is the upskill program?',
#  'what upskill program do you have?',
#  'what does upskill program mean?',
#  'upskill program?',
#  'who should participate in the upskill program?',
#  'upskill program is for whom?',
#  'how does upskill program help me?',
#  'what can I benefit from upskill program?',
#  'what can I learn from upskill program?',
#  'where can I learn more about upskill program?',
#  'where to find out upskill program?',
#  'what is the Practical Data Science Training?',
#  'Practical Data Science Training?',
#  'what Practical Data Science Training do you have?',
#  'what does Practical Data Science Training mean?',
#  'how does Practical Data Science Training help me?',
#  'what can I benefit from Practical Data Science Training?',
#  'what can I learn from Practical Data Science Training?',
#  'who should participate in Practical Data Science Training?',
#  'Practical Data Science Training is for whom?',
#  'where can I learn more about Practice Data Science Training?',
#  'where to find out Practice Data Science Training?',
#  'what is the Pre-Conference Training?',
#  'Pre-Conference Training?',
#  'what does Pre-Conference Training mean?',
#  'who should participate in Pre-Conference Training?',
#  'Pre-Conference Training is for whom?',
#  'how does Pre-Conference Training help me?',
#  'what can I benefit from Pre-Conference Training?',
#  'what can I benefit from Pre-Conference Training?',
#  'where can I learn more about Pre-Conference Training?',
#  'where to find out Pre-Conference Training?']

# %%
######## auto input user questions

# input user question
new_question = """what is nba?"""
## embedding question
encoded_question = rmds_model.encode([new_question])

## calculate the distance
distances = spatial.distance.cdist(np.array(encoded_question), question_embeddings, 'cosine')[0]
results = zip(range(len(distances)), distances)
results = sorted(results, key=lambda x: x[1])

for idx, distance in results[0:3]: # just getting top 1
    if 1-distance>0.5:
      print(f"Your answer:")
      # print(question_texts[idx])
      print(f"cosine_score:{1-distance}, {corresponding_answer[idx]}")
    else:
      print("No")
# Out:
# No
# No
# No

# %%
print(question_text[1])
corresponding_answer[1]
# Out:
# What is RMDS?
# 'Global Association for Research Methods and Data Science is the leading community-centered data science research organization, creating a global platform which enables people to meet, learn, and collaborate with fellow data science professionals to solve problems. RMDS Lab manages GRMDS community.'

# %%
results
# Out:
# [(3, 0.6305254458353631),
#  (1, 0.646847260918596),
#  (82, 0.6502782181283325),
#  (417, 0.6535311109822594),
#  (13, 0.6541258664879501),
#  (415, 0.6555561689693297),
#  (414, 0.6617331744575232),
#  (418, 0.6700938102192653),
#  (409, 0.6726551318984781),
#  (416, 0.6728784870336614),
#  (83, 0.6759569765808487),
#  (400, 0.6766265510165783),
#  (443, 0.6788716203218825),
#  (75, 0.6811160474712155),
#  (436, 0.6825916570913113),
#  (447, 0.6825916570913113),
#  (60, 0.6839600255606431),
#  (428, 0.6844248721604869),
#  (49, 0.6874340229395847),
#  (14, 0.6901151387719335),
#  (437, 0.6907656462455569),
#  (411, 0.6942244254633491),
#  (439, 0.6951912620683909),
#  (86, 0.6960820876216774),
#  (9, 0.6966628603686558),
#  (77, 0.6978499097044712),
#  (431, 0.7064240990568109),
#  (91, 0.7068422860193705),
#  (413, 0.7068669934693781),
#  (446, 0.7070433488731607),
#  (12, 0.7080705510979424),
#  (55, 0.7082867133160848),
#  (410, 0.709897717224957),
#  (401, 0.7107894475987206),
#  (81, 0.7110140381001073),
#  (432, 0.7113090257270671),
#  (64, 0.7114516571426822),
#  (59, 0.7116672676911783),
#  (28, 0.7117486230113707),
#  (51, 0.7144841749744959),
#  (455, 0.7178682147100832),
#  (76, 0.7179331710261662),
#  (52, 0.7184705503412179),
#  (50, 0.7195530408146559),
#  (42, 0.7196418746810762),
#  (79, 0.7218785004833503),
#  (396, 0.723777885396029),
#  (406, 0.7244434875932761),
#  (408, 0.7260177146825977),
#  (459, 0.7262865324072469),
#  (53, 0.728584423296077),
#  (10, 0.7294094190487596),
#  (402, 0.7299573023957828),
#  (412, 0.7300207951759966),
#  (61, 0.730237980797974),
#  (394, 0.7303007424092559),
#  (40, 0.7314196841727367),
#  (404, 0.731707292905853),
#  (47, 0.7331405187354201),
#  (451, 0.7332579144881887),
#  (80, 0.7338146465844859),
#  (78, 0.7367164587564938),
#  (23, 0.738474239178347),
#  (84, 0.7401488101237412),
#  (435, 0.7406309064439505),
#  (85, 0.7417846109024943),
#  (438, 0.7418659977694726),
#  (403, 0.7420265145726068),
#  (407, 0.7421254908961241),
#  (433, 0.7425111443878014),
#  (405, 0.7463201979688894),
#  (11, 0.7463531402634798),
#  (444, 0.7464315516686684),
#  (442, 0.7473657887978195),
#  (65, 0.7474590089673916),
#  (383, 0.7476323099588298),
#  (39, 0.7479538905536085),
#  (167, 0.7503165660462486),
#  (90, 0.7515583450662224),
#  (87, 0.7537431084452513),
#  (45, 0.75547680555791),
#  (384, 0.7577271037154985),
#  (373, 0.7583871900747946),
#  (434, 0.7587357301713027),
#  (445, 0.7587357301713027),
#  (36, 0.7593044270257194),
#  (460, 0.7597880619478857),
#  (453, 0.7597930728895319),
#  (429, 0.7599039786420047),
#  (112, 0.7602054961109883),
#  (452, 0.7605312660290949),
#  (0, 0.7610470369720143),
#  (422, 0.7612365463016767),
#  (108, 0.76187374760389),
#  (68, 0.7638257486526961),
#  (89, 0.7639341672260868),
#  (96, 0.7648223864569947),
#  (88, 0.7653946752849942),
#  (441, 0.7668606270822474),
#  (378, 0.7670533815898872),
#  (32, 0.7670650381517391),
#  (22, 0.7672854001088674),
#  (385, 0.7686322932452343),
#  (8, 0.7693139552748515),
#  (166, 0.7699146003558167),
#  (92, 0.7720157000230945),
#  (448, 0.7724946119146747),
#  (387, 0.7735197634115495),
#  (41, 0.7738859800101737),
#  (457, 0.7746013201207325),
#  (381, 0.77485400836926),
#  (170, 0.7748990283610745),
#  (426, 0.7761120248751414),
#  (66, 0.7763221730232833),
#  (458, 0.7781055742666756),
#  (33, 0.7793982145141708),
#  (67, 0.7798099165358515),
#  (159, 0.7805679963354106),
#  (376, 0.7809698315720774),
#  (499, 0.780983170217938),
#  (162, 0.7810487486803864),
#  (5, 0.7820223242825439),
#  (372, 0.782758673382808),
#  (382, 0.7839233646941672),
#  (165, 0.7847839788921082),
#  (46, 0.7850537562864083),
#  (164, 0.7868587725241046),
#  (427, 0.7871248431385188),
#  (501, 0.7872576450641992),
#  (399, 0.788282751790671),
#  (107, 0.7887935067762878),
#  (106, 0.7889194227339567),
#  (43, 0.7899048814764953),
#  (97, 0.7902438606970615),
#  (93, 0.7915804789797336),
#  (395, 0.7922044081200824),
#  (103, 0.792313171148828),
#  (113, 0.7928015738649181),
#  (449, 0.7937727995768725),
#  (56, 0.794611857562799),
#  (44, 0.7946241137305408),
#  (369, 0.7955401880266175),
#  (430, 0.7971477995900398),
#  (450, 0.7971663029502996),
#  (456, 0.7979456189718683),
#  (440, 0.7980201127406372),
#  (62, 0.7987075095158831),
#  (7, 0.7987617557368586),
#  (397, 0.7992174894279997),
#  (423, 0.7997557683823814),
#  (497, 0.8017637495127663),
#  (470, 0.8023798110506167),
#  (398, 0.8024470152019209),
#  (58, 0.8030204226383494),
#  (48, 0.8033727924487394),
#  (16, 0.8034424297659009),
#  (15, 0.8034475451991151),
#  (272, 0.8039024986678247),
#  (168, 0.8039837704784554),
#  (161, 0.8040198543712685),
#  (371, 0.8043377223293853),
#  (98, 0.8047775258922237),
#  (17, 0.8056261113514607),
#  (242, 0.8068314985643832),
#  (302, 0.8101914359364722),
#  (6, 0.8102548054608234),
#  (506, 0.8106148005429548),
#  (163, 0.8108121446428064),
#  (317, 0.8112687283305031),
#  (25, 0.8123773387559523),
#  (290, 0.8129795865015881),
#  (104, 0.8133441210849333),
#  (115, 0.8135641734661961),
#  (393, 0.8136769335567574),
#  (109, 0.814141878331631),
#  (29, 0.8163526074703635),
#  (2, 0.8164206778281033),
#  (380, 0.8168083458175459),
#  (500, 0.8169770475940761),
#  (20, 0.818188595525449),
#  (26, 0.818894141688651),
#  (102, 0.8202332724185855),
#  (63, 0.8203708330973288),
#  (160, 0.8204121366772913),
#  (454, 0.8209569700414172),
#  (101, 0.8209586292442473),
#  (172, 0.8231929867846897),
#  (37, 0.8235115361749404),
#  (389, 0.8245382981317643),
#  (289, 0.8245904359334253),
#  (24, 0.8248543890089379),
#  (125, 0.8259658411515809),
#  (471, 0.8267524819163238),
#  (173, 0.8270944756514654),
#  (392, 0.827338649168131),
#  (291, 0.8287508418775511),
#  (287, 0.8288574500256802),
#  (105, 0.8291288813225726),
#  (386, 0.82992345584279),
#  (505, 0.830346705753727),
#  (467, 0.8303538702445685),
#  (469, 0.831901354912335),
#  (474, 0.8322403032120478),
#  (4, 0.8322488773306297),
#  (245, 0.8327061415280028),
#  (57, 0.8327404054295684),
#  (390, 0.8328119355815101),
#  (111, 0.8335898444129608),
#  (171, 0.8341981904109106),
#  (114, 0.8342049865207826),
#  (152, 0.835807075983882),
#  (334, 0.8361229584402583),
#  (502, 0.8362823938057302),
#  (473, 0.837150075106718),
#  (169, 0.837188557067956),
#  (121, 0.8371962913130315),
#  (71, 0.8375039595488142),
#  (18, 0.8379301428605489),
#  (271, 0.8380941205228748),
#  (286, 0.841066921958953),
#  (99, 0.8411606506736959),
#  (19, 0.8411907593430962),
#  (69, 0.8418688639460937),
#  (241, 0.8421057303638706),
#  (269, 0.842835194226316),
#  (54, 0.8428878864123769),
#  (185, 0.8441570175133277),
#  (182, 0.8450570887209433),
#  (299, 0.8452346193043355),
#  (127, 0.8456269961536129),
#  (503, 0.8456688958751277),
#  (504, 0.8456688958751277),
#  (305, 0.8462362757155286),
#  (314, 0.8468565606307312),
#  (370, 0.8473599540164063),
#  (257, 0.8482764801954316),
#  (368, 0.848586343704094),
#  (320, 0.8487312803886664),
#  (244, 0.8488468255652728),
#  (498, 0.8490586691522093),
#  (248, 0.8498353707137544),
#  (301, 0.850522665445832),
#  (38, 0.8509468114422614),
#  (21, 0.8513221729257626),
#  (184, 0.8513338505789649),
#  (155, 0.8515886905365249),
#  (463, 0.8523329286809883),
#  (304, 0.8529304749607157),
#  (285, 0.8538054475386758),
#  (300, 0.8554286929098036),
#  (335, 0.8560165557611848),
#  (294, 0.8564643311206138),
#  (472, 0.8567707325099831),
#  (391, 0.8568753618845999),
#  (388, 0.8569367431542445),
#  (240, 0.8573070328970497),
#  (267, 0.8577112854944565),
#  (239, 0.8577748925958525),
#  (126, 0.8582721422927005),
#  (288, 0.8588445384762804),
#  (307, 0.8589397823079942),
#  (100, 0.8590482760936899),
#  (279, 0.8593306994582429),
#  (424, 0.8602149671656025),
#  (234, 0.8603832630828172),
#  (268, 0.8604259878580285),
#  (274, 0.8604711210258699),
#  (464, 0.8605461593660053),
#  (419, 0.8609144239642308),
#  (316, 0.8620520699311756),
#  (303, 0.8620557120069157),
#  (421, 0.8640109459258193),
#  (315, 0.8640368411032568),
#  (247, 0.8648216514861718),
#  (297, 0.8654871059810476),
#  (379, 0.8657196616379292),
#  (468, 0.8658310749654061),
#  (236, 0.8663344418415775),
#  (136, 0.867363305953722),
#  (479, 0.8675552533160287),
#  (332, 0.8686117589788467),
#  (319, 0.8699096583902022),
#  (420, 0.8701110617242054),
#  (282, 0.8702178727209093),
#  (179, 0.870820051476963),
#  (298, 0.8708688404484677),
#  (122, 0.8710235339857775),
#  (95, 0.8711601244363729),
#  (425, 0.871372000566425),
#  (181, 0.8713926697440011),
#  (183, 0.8716993386549181),
#  (120, 0.8721650917195843),
#  (313, 0.8727244750776941),
#  (461, 0.8740395971799109),
#  (493, 0.8741199767072771),
#  (259, 0.8746337800635107),
#  (27, 0.8747436250731774),
#  (292, 0.8750999035807514),
#  (284, 0.8758381164271785),
#  (246, 0.8760584794966602),
#  (254, 0.8765086773852417),
#  (293, 0.8768375485658728),
#  (149, 0.8777672058233197),
#  (151, 0.877831284403165),
#  (322, 0.8782606428363237),
#  (311, 0.8787235204789965),
#  (243, 0.8787432813388836),
#  (110, 0.8791194724712191),
#  (281, 0.8797713872156195),
#  (377, 0.8800372425666011),
#  (270, 0.8802315631149565),
#  (174, 0.8807126181545135),
#  (158, 0.8809316040321931),
#  (278, 0.8816571716795648),
#  (275, 0.8816886533797594),
#  (312, 0.8818720966303397),
#  (323, 0.8820733469414671),
#  (94, 0.8822157952945114),
#  (117, 0.8822186791926112),
#  (309, 0.8824671714050776),
#  (375, 0.88267806963132),
#  (123, 0.8831670683573319),
#  (283, 0.883253909102349),
#  (337, 0.8833914722722263),
#  (306, 0.8843512101032649),
#  (227, 0.8843612630490338),
#  (256, 0.8871590052189485),
#  (466, 0.8872356133315198),
#  (137, 0.8872541552201717),
#  (321, 0.8879345466647073),
#  (237, 0.8879879001994851),
#  (35, 0.8880910236369544),
#  (318, 0.889279196399604),
#  (477, 0.8892956716057798),
#  (347, 0.8893707546592375),
#  (116, 0.8899930607437216),
#  (331, 0.8902304849667516),
#  (238, 0.8909323468977781),
#  (157, 0.8910296945867289),
#  (295, 0.8911766370964611),
#  (144, 0.8916202225760557),
#  (177, 0.8919542164788898),
#  (276, 0.892168777155117),
#  (277, 0.8922715193756361),
#  (308, 0.8932478202934456),
#  (465, 0.8933394384967579),
#  (338, 0.8938338097426652),
#  (147, 0.8957279595537736),
#  (296, 0.8964529099379388),
#  (361, 0.8973320680602828),
#  (485, 0.8986069015596435),
#  (73, 0.8987148529574126),
#  (475, 0.8988664653986471),
#  (153, 0.8990456937034954),
#  (476, 0.9000764599183941),
#  (253, 0.9001132660546742),
#  (264, 0.9007882643488759),
#  (154, 0.9010802560355913),
#  (148, 0.9011808378276739),
#  (150, 0.9014122913326572),
#  (480, 0.9017628494046592),
#  (70, 0.9021388169146175),
#  (186, 0.9023708623811918),
#  (176, 0.9039923276263802),
#  (156, 0.9041125124621299),
#  (260, 0.9043746138776114),
#  (462, 0.9045359738538905),
#  (187, 0.9048556587571808),
#  (265, 0.9049215791030462),
#  (252, 0.9050792882161811),
#  (178, 0.9051900885081517),
#  (74, 0.9052238491513456),
#  (280, 0.9065220402855001),
#  (142, 0.9069153221630231),
#  (329, 0.9074142234802375),
#  (262, 0.9075009047611655),
#  (139, 0.907570313952063),
#  (266, 0.9078724119855147),
#  (363, 0.9079520106100348),
#  (255, 0.9085738785440629),
#  (229, 0.9085958598354341),
#  (327, 0.9086528211727547),
#  (310, 0.9090410975441514),
#  (143, 0.9091858160651741),
#  (235, 0.9092162941987629),
#  (333, 0.9097915760918549),
#  (273, 0.9098582400249221),
#  (364, 0.9100989320205185),
#  (494, 0.9103930825195707),
#  (180, 0.9106055610236691),
#  (146, 0.9106761157531998),
#  (330, 0.9107822451162872),
#  (188, 0.9112745197490177),
#  (131, 0.9117686632833414),
#  (328, 0.9125378628550691),
#  (34, 0.9127697839791082),
#  (356, 0.91280906479086),
#  (489, 0.9128738257221592),
#  (263, 0.91332126783787),
#  (197, 0.9144617617732839),
#  (366, 0.9147478590144945),
#  (358, 0.9150241311898846),
#  (486, 0.9154211523634731),
#  (249, 0.9161695410805523),
#  (261, 0.9182217152988301),
#  (336, 0.9183501836165687),
#  (357, 0.9186611815899827),
#  (346, 0.9187197168178005),
#  (484, 0.9188227782390553),
#  (251, 0.9199051703258196),
#  (135, 0.9205228830950927),
#  (344, 0.9209245380245279),
#  (212, 0.9214008311242466),
#  (324, 0.9214984600957387),
#  (488, 0.9216925939315623),
#  (140, 0.9230248790994966),
#  (128, 0.9230405437640663),
#  (226, 0.9231244750085531),
#  (481, 0.9231829019803677),
#  (30, 0.9235360103786143),
#  (230, 0.9246311014050591),
#  (130, 0.9251362349883192),
#  (133, 0.925224659044344),
#  (258, 0.9260263867156014),
#  (326, 0.9261447584754066),
#  (124, 0.9262468426549688),
#  (223, 0.9263007240276637),
#  (352, 0.9275729451511556),
#  (224, 0.9277877969311321),
#  (491, 0.9283314728843169),
#  (483, 0.9283914078018641),
#  (482, 0.928594632680898),
#  (353, 0.9296952390667369),
#  (134, 0.9327711742368443),
#  (175, 0.9332892990225248),
#  (138, 0.9338047478492336),
#  (351, 0.9339903004386898),
#  (365, 0.9341674535352503),
#  (222, 0.9343582490307629),
#  (339, 0.9345786822907186),
#  (490, 0.93475432618084),
#  (199, 0.9369481864579988),
#  (349, 0.937040570198058),
#  (359, 0.9370998386897995),
#  (362, 0.937329352539743),
#  (495, 0.9374192116917741),
#  (200, 0.9381275217447276),
#  (360, 0.9387893742115634),
#  (118, 0.9391666173064372),
#  (132, 0.9417140106860622),
#  (367, 0.9422325011615381),
#  (72, 0.9433029018357657),
#  (209, 0.9441394150115145),
#  (214, 0.9442466204087732),
#  (119, 0.944437956683764),
#  (342, 0.9444413522858911),
#  (194, 0.9454179001984957),
#  (492, 0.9458072915603228),
#  (193, 0.946072129643315),
#  (355, 0.9468825848645036),
#  (250, 0.9472634474487561),
#  (145, 0.9475067426521068),
#  (232, 0.9477377313071667),
#  (343, 0.9480391236413865),
#  (31, 0.94851430673203),
#  (196, 0.9516182473235133),
#  (191, 0.9520966226895569),
#  (228, 0.9524315664972427),
#  (496, 0.9528672364483554),
#  (341, 0.9544362770392225),
#  (215, 0.955244884223043),
#  (141, 0.9560745103901277),
#  (129, 0.9574641388192002),
#  (221, 0.9578556778255839),
#  (348, 0.9580967573444702),
#  (325, 0.959437331198903),
#  (487, 0.9600197254047037),
#  (198, 0.960168006791862),
#  (225, 0.960518860187598),
#  (345, 0.9609246840197224),
#  (374, 0.9612321038561066),
#  (211, 0.9615164047005185),
#  (202, 0.961589759985949),
#  (189, 0.9620837754975653),
#  (201, 0.9623661058450604),
#  (208, 0.9626926120047454),
#  (233, 0.9634200651273405),
#  (219, 0.9648879738378195),
#  (216, 0.9660443567675872),
#  (206, 0.9663759315326254),
#  (350, 0.966513024144309),
#  (354, 0.973093728069376),
#  (192, 0.9733903885904146),
#  (217, 0.9739509377237735),
#  (207, 0.9757836546489992),
#  (203, 0.9763433775422699),
#  (478, 0.9769959570838322),
#  (204, 0.9773434013301134),
#  (340, 0.9788652976007478),
#  (218, 0.979983692940588),
#  (231, 0.9809889910210808),
#  (195, 0.9820638526164664),
#  (220, 0.9821742324527246),
#  (213, 0.9917138552845113),
#  (210, 1.0014887762609506),
#  (190, 1.0147974758658738),
#  (205, 1.0318593214450953)]

# %%
# convert it to a function
def QA_bot(input_question,question_embeddings, corresponding_answer):
  # input user question
  new_question = input_question
  ## embedding question
  encoded_question = rmds_model.encode([new_question])

  ## calculate the distance
  distances = spatial.distance.cdist(np.array(encoded_question), question_embeddings, 'cosine')[0]
  results = zip(range(len(distances)), distances)
  results = sorted(results, key=lambda x: x[1])
  
  for idx, distance in results[0:1]: # just getting top 1
      return idx,results[0:1],"Your answer:\n{}\n".format(corresponding_answer[idx])

# %%
#Backup question list
Question_Backup = ['What is RMDS Lab?'
,'Why choose RMDS Lab?'
,'Where can I learn more about RMDS?'
,'What courses do you have?'
,'What kind of events do you have?'
,'What is NFT Market?'
,'Where can I learn more about NFT Market?'
,'What is NFT?']

# %%
cate_B_list = [str(x).lower().split(' /') for x in df_2[3]]
list_B = []
for i in cate_B_list:
  for j in i:
    if j not in list_B and j != 'nan':

      list_B.append(j)
print(list_B)
# Out:
# ['rmds', ' mission', ' goal', 'service', ' product', 'study', ' course', ' class', ' training', 'event ', 'event', 'project portal', 'data science portfolio', 'rmds exchange', 'nft market', 'rm4es', ' workflow', 'researchmap', 'ecosystem', 'big data', ' ai', ' business', ' data science', 'financial technology', ' cryptocurrency', 'ai bias', ' surveillance', 'data analysis', 'cdi', 'ai', ' ethics', ' decision making', 'webinar series', 'covid', ' literature review', ' model', 'python', 'knime', ' basic', 'chatbot', ' healthcare', 'machine learning', ' ml', 'grmds', 'imdata', 'quaterly competition', 'nft', 'nft exchange', 'upskill program', ' pi program', ' internship', 'impact score', 'recommendation system', 'practical data science training', 'pre-conference training']

# %%
#StopWords function
nlp = spacy.load('en_core_web_sm')

def CleanStopWords(question):
  cate_B_list = [str(x).lower().split(' /') for x in df_2[3]]
  list_B = []
  hate_word_list = ['hate','detestation','disgust','enmity','hatred','horror','loath','malice']
  for i in cate_B_list:
    for j in i:
      if j not in list_B and j != 'nan':
        list_B.append(j)
  StopWords = ['is','are','be','should','does','do','can','that','to','for','on','at','from','by','and']
  line = nlp(question)
  question_tokens = [str(token).lower() for token in line if str(token) not in StopWords]
  bonus_count = 0
  hate_count = 0
  bonus_list = []
  for token in question_tokens:
    if token in list_B:
      bonus_list.append(token)
      bonus_count+=1
    if token in hate_word_list:
      hate_count+=1
  return ' '.join(question_tokens), bonus_count, bonus_list, hate_count  

CleanStopWords('what is rmds and imdata, I hate rmds ?')
# Out:
# ('what rmds imdata , i hate rmds ?', 3, ['rmds', 'imdata', 'rmds'], 1)

# %%
############## bert similar version ##############
question = input("\nPlease enter your question: \n")
question = CleanStopWords(question)
import random
condition_N = True
while True:
  if question in ["No", "no","not thing", "that's it","N"]:
    print("\nSee you next time!")
    break
  # question_answer(question)
  default = ["Sorry, I don't understand what you mean.","Sorry about this. If you need further assistance, you can email us at info@rmdslab.com or give us a call 1-626-432-7266"]
  index, sim_a, ans = QA_bot(question, question_embeddings, corresponding_answer)
  sim_b = list(sim_a[0])[1]
  if sim_b > 0.3 or question.lower() in ["what","why","where","when","how"]:
    print(default[random.randint(0,1)])
    question = input("\nOR Please enter your question: \n")
    question = CleanStopWords(question)
  else:
    print(ans)
    
    answers = df_2.loc[df_2[1]==question_text[index]]
    x = answers[3].to_list()
    y = ''.join(x)

    category = df_2.groupby(0).apply(lambda x: x.iloc[0]).reset_index(drop=True)
    print(category)
    index = []
    question_list=[]
    count = 0
    num = 1
    for x in category[3]:
      if x == y:
        index.append(count)
      count+=1
    for i in index:
      print(num,category[1][i])
      question_list.append([num,category[1][i]])
      num+=1
    num_2 = num
    # Backup Questions
    if num<6:
      Question_Backup_2 = [x for x in Question_Backup if str(x) not in question_list]
      backup_list = random.choices(Question_Backup_2, k=int(6-num))
      print("\n*More you might want to know*")
      for x in backup_list:
        print(num_2,x)
        question_list.append([num_2,x])
        num_2+=1
    flag = True
    flag_N = False
    while flag:
      response = input("\nDo you want to know more about {}?(You can type other questions) \n".format(y))
      if response.isnumeric():
        if response in ["{:d}".format(x) for x in range(1,num_2)]:
          question = CleanStopWords(question_list[int(response)-1][1])
          flag = False
        else:
          print("\nPlease enter an integer in the list.")
          
      elif response not in ["No", "no","not thing", "that's it","N"]:
        # question = input("\nPlease enter your question: \n")
        question = CleanStopWords(response)
        flag = False
        condition_N = True
      else:
        print("\nSee you next time!")
        flag = False
        flag_N = True
    if flag_N == True:
      break
# Out:
# Please enter your question:
# dd
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BOYUAN~1\AppData\Local\Temp/ipykernel_45328/1421877167.py in <module>
#       1 ############## bert similar version ##############
#       2 question = input("\nPlease enter your question: \n")
# ----> 3 question = CleanStopWords(question)
#       4 import random
#       5 condition_N = True
#
# NameError: name 'CleanStopWords' is not defined

# %%
#############################################

# %% [markdown]
# # Complex bert model (BertForQuestionAnswering) !!!

# %%
# Loading BERT model already fine-tuned on SQuAD Question Answer Dataset. This 1.3 GB download and may take sometime
# Note that we are using uncased model so all answers will be in lower case
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %%
# Getting bert tokenizer
tokenizer_for_bert = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %% [markdown]
# ## Main function (Bert)

# %%
def bert_answering_machine ( question, passage, max_len =  512):
    ''' Function to provide answer from passage for question asked.
        This function takes question as well as the passage 
        It retuns answer from the passage, along with start/end token index for the answer and start/end token scores
        The scores can be used to rank answers if we are searching answers for same question in multiple passages
        Value of max_len can not exceed 512. If length of question + passage + special tokens is bigger than max_len, function will truncate extra portion.
        
    '''
  
    #Tokenize input question and passage. Keeping maximum number of tokens as specified by max_len parameter. This will also add special tokens - [CLS] and [SEP]
    input_ids = tokenizer_for_bert.encode (question, passage,  max_length= max_len, truncation=True)  
    ## ↑ [101,2029,2110,2198,1005,1055,2767,3268,102,2026,2171,2003,2198,1012,1045,2444,1999,2624,4560,1010,2662,1012,6487,2003,2026,2767,1012,2002,3268,1999,5862,1010,2899,102]
    
    #Getting number of tokens in 1st sentence (question) and 2nd sentence (passage)
    cls_index = input_ids.index(102) #Getting index of first SEP token
    len_question = cls_index + 1       # length of question (1st sentence)
    len_answer = len(input_ids)- len_question  # length of answer (2nd sentence)
    
    
    #BERT need Segment Ids to understand which tokens belong to sentence 1 and which to sentence 2
    segment_ids =  [0]*len_question + [1]*(len_answer)  #Segment ids will be 0 for question and 1 for answer
    
    #Converting token ids to tokens
    tokens = tokenizer_for_bert.convert_ids_to_tokens(input_ids) 
    ## ↑ ['[CLS]','which','state','john',"'",'s','friend','lives','[SEP]','my','name','is','john','.','i','live','in','san','jose',',','california','.','rob','is','my','friend','.','he','lives','in','seattle',',','washington','[SEP]']
    
    # getting start and end scores for answer. Converting input arrays to torch tensors before passing to the model
    start_token_scores = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]) )[0]
    end_token_scores = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]) )[1]
   
    #Converting scores tensors to numpy arrays so that we can use numpy functions
    start_token_scores = start_token_scores.detach().numpy().flatten()
    end_token_scores = end_token_scores.detach().numpy().flatten()
    
    #Picking start index and end index of answer based on start/end indices with highest scores
    answer_start_index = np.argmax(start_token_scores)
    answer_end_index = np.argmax(end_token_scores)
   
    #Getting scores for start token and end token of the answer. Also rounding it to 2 decimal digits
    start_token_score = np.round(start_token_scores[answer_start_index], 2)
    end_token_score = np.round(end_token_scores[answer_end_index], 2)
    
   
    #Combining subwords starting with ## so that we can see full words in output. Note tokenizer breaks words which are not in its vocab.
    answer = tokens[answer_start_index] #Answer starts with start index, we got based on highest score
    for i in range(answer_start_index + 1, answer_end_index + 1):
        if tokens[i][0:2] == '##':  # Token for a splitted word starts with ##
            answer += tokens[i][2:] # If token start with ## we remove ## and combine it with previous word so as to restore the unsplitted word
        else:
            answer += ' ' + tokens[i]  # If token does not start with ## we just put a space in between while combining tokens
            
    # Few patterns indicating that BERT does not get answer from the passage for question asked
    if ( answer_start_index == 0) or (start_token_score < 0 ) or  (answer == '[SEP]') or ( answer_end_index <  answer_start_index):
        answer = "Sorry!, I could not find  an answer in the passage."
    
    return ( answer_start_index, answer_end_index, start_token_score, end_token_score,  answer)
    # return (answer)

# %%
#Testing function
bert_answering_machine ("Which state john's friend lives", 'My name is John. I live in San Jose, California. Rob is my friend. He lives in Seattle, Washington')
# Out:
# (32, 32, 6.13, 6.94, 'washington')

# %% [markdown]
# ## BERT_QA bot from Multiple_Texts

# %%
#  to get answer from an array of passages
def get_answer(q, p_array):
    score_list = []
    ans_list = []
    j_list = []
    for j in range (len(p_array)):  
        #p = preprocess(p_array[j] )
        p = p_array[j] 

        start, end , start_score, end_score,  ans = bert_answering_machine (q, p)
        #print( '\nText num:', j, 'Score:', start_score, end_score, '\nBERT Answer:', ans)
        
        if (start != 0) and (start_score > 0.25)  and (ans != '[SEP]')  :
            score_list.append(str(start_score) + ' and ' + str(end_score))
            ans_list.append(ans)
            j_list.append(j)
        else:
            text_num = None
            token_scores = None
            answer = "No Answer From BERT"

            
    if len(score_list) > 0 :
        ind = np.argmax(score_list)
        #print( 'Text number:', j_list[ind], ',  Token Scores:', score_list[ind], '\nBERT Answer:', ans_list[ind])
        text_num = j_list[ind]
        token_scores = score_list[ind]
        answer = ans_list[ind]
    else:
        text_num = None
        token_scores = None
        answer = "No Answer From BERT"
    return text_num, token_scores, answer

# %%
# passing 3 pagges and get_answer gets the  answer from best passege
passages_array=["I am a student , I study in UC Davis. I like to play Tennis",
    "John is a 10 year old boy. He is the son of Robert Smith.  Elizabeth Davis is Robert's wife. She teaches at UC Berkeley. Sophia Smith is Elizabeth's daughter. She studies at UC Davis", 
 "My name is John. I live in San Jose, California. Rob is my friend. He lives in Seattle, Washington, My sister is Kelly. " ]

for i in range(len(passages_array)):
    print (f'Passage: {i} : {passages_array[i]}\n')
question ="Which college does John's sister attend"  

passage_num, scores, answer = get_answer(question, passages_array)

print (f'The question: {question} \n Answer: {answer} , Passage Index Where Answer Was Found: {passage_num}, Scores: {scores}')
# Out:
# Passage: 0 : I am a student , I study in UC Davis. I like to play Tennis
#
# Passage: 1 : John is a 10 year old boy. He is the son of Robert Smith.  Elizabeth Davis is Robert's wife. She teaches at UC Berkeley. Sophia Smith is Elizabeth's daughter. She studies at UC Davis
#
# Passage: 2 : My name is John. I live in San Jose, California. Rob is my friend. He lives in Seattle, Washington, My sister is Kelly.
#
# The question: Which college does John's sister attend
#  Answer: uc davis , Passage Index Where Answer Was Found: 1, Scores: 5.83 and 6.35

# %% [markdown]
# ## Document Segmenting

# %% [markdown]
# Now that we have our document corpus, we need to make sure that each document is short enough to fit into the 512 token limit of BERT. If a document is longer than 512 tokens, we'll simply segment it into multiple smaller chunks and add them to the final corpus.

# %%
def segment_documents(docs, max_doc_length=450):
  # List containing full and segmented docs
  segmented_docs = []

  for doc in docs:
    # Split document by spaces to obtain a word count that roughly approximates the token count
    split_to_words = doc.split(" ")

    # If the document is longer than our maximum length, split it up into smaller segments and add them to the list 
    if len(split_to_words) > max_doc_length:
      for doc_segment in range(0, len(split_to_words), max_doc_length):
        segmented_docs.append( " ".join(split_to_words[doc_segment:doc_segment + max_doc_length]))

    # If the document is shorter than our maximum length, add it to the list
    else:
      segmented_docs.append(doc)

  return segmented_docs

# %%
# contents = segment_documents(df_long_text['Content'].to_list())
# contents

# %% [markdown]
# ## Finding Relevant Documents

# %% [markdown]
# Next, our goal is to find within this corpus the subset of documents that are most likely to contain our answer, because running every single document through our BERT model is expensive and doesn't help us narrow down a good answer. For this example, we'll simply use the scikit-learn TF-IDF vectorizer to convert our documents and our query into vectors.
#
# The document vectors with the highest cosine similarity to our query vector will be the best candidates to search for our answer, and we will feed these top candidate documents into the SQUAD model to get our predicted answers.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def get_top_k_articles(query, docs, k=2):

  # Initialize a vectorizer that removes English stop words
  vectorizer = TfidfVectorizer(analyzer="word", stop_words='english')

  # Create a corpus of query and documents and convert to TFIDF vectors
  query_and_docs = [query] + docs
  matrix = vectorizer.fit_transform(query_and_docs)

  # Holds our cosine similarity scores
  scores = []

  # The first vector is our query text, so compute the similarity of our query against all document vectors
  for i in range(1, len(query_and_docs)):
    scores.append(cosine_similarity(matrix[0], matrix[i])[0][0])

  # Sort list of scores and return the top k highest scoring documents
  sorted_list = sorted(enumerate(scores), key=lambda x: x[1], reverse=True)
  top_doc_indices = [x[0] for x in sorted_list[:k]]
  top_docs = [docs[x] for x in top_doc_indices]
  
  return top_docs

# %%
##### test
# myself test based on own csv file
df_long_text = pd.read_excel("(for test)[Chatbot] Content - Copy.xlsx")

# Segment our documents (If a document is longer than 512 tokens, we'll simply segment it into multiple smaller chunks and add them to the final corpus.)
contents = segment_documents(df_long_text['Content'].to_list())

# question ="when was nba founded?"  
question ="what is nba?"



# Retrieve the top k most relevant documents to the query ()
candidate_docs = get_top_k_articles(question, contents, 2)

passage_num, scores, answer = get_answer(question, candidate_docs)
print(f'Answer: {answer}')

# print (f'Answer: {answer} , Passage Index Where Answer Was Found: {passage_num}, Scores: {scores}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\BOYUAN~1\AppData\Local\Temp/ipykernel_7560/1817507245.py in <module>
#       1 ##### test
#       2 # myself test based on own csv file
# ----> 3 df_long_text = pd.read_excel("(for test)[Chatbot] Content - Copy.xlsx")
#       4
#       5 # Segment our documents (If a document is longer than 512 tokens, we'll simply segment it into multiple smaller chunks and add them to the final corpus.)
#
# ~\Desktop\Python\Anacondo\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Desktop\Python\Anacondo\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\Desktop\Python\Anacondo\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# ~\Desktop\Python\Anacondo\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# ~\Desktop\Python\Anacondo\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '(for test)[Chatbot] Content - Copy.xlsx'

# %%
### convert it to function:
def bert_text_search_start_end_QA(que, documents):
  # Segment our documents (If a document is longer than 512 tokens, we'll simply segment it into multiple smaller chunks and add them to the final corpus.)
  contents = segment_documents(documents)

  question =que

  # Retrieve the top k most relevant documents to the query ()
  candidate_docs = get_top_k_articles(question, contents, 2)

  passage_num, scores, answer = get_answer(question, candidate_docs)
  return answer

# %% [markdown]
# # Combination version (version02)!!!!!!!!!

# %%
df_long_text = pd.read_excel("(for test)[Chatbot] Content - Copy.xlsx")
contents = segment_documents(df_long_text['Content'].to_list())

# %%
# convert it to a function
def QA_bot(input_question,question_embeddings, corresponding_answer):
  ## embedding question
  encoded_question = rmds_model.encode([input_question])

  ## calculate the distance
  distances = spatial.distance.cdist(np.array(encoded_question), question_embeddings, 'cosine')[0]
  results = zip(range(len(distances)), distances)
  results = sorted(results, key=lambda x: x[1])

  for idx, distance in results[0:1]: # just getting top 1
      print(f"Your answer:")
      print(corresponding_answer[idx])

# %%
###################### test version(convert it to function) ######################
def combination_model(input_question, question_embeddings, corresponding_answer):
  ## embedding question
  encoded_question = rmds_model.encode([input_question])

  ## calculate the distance
  distances = spatial.distance.cdist(np.array(encoded_question), question_embeddings, 'cosine')[0]
  results = zip(range(len(distances)), distances)
  results = sorted(results, key=lambda x: x[1])

  for idx, distance in results[0:1]: # just getting top 1
      if 1-distance>0.5:
        print(f"Your answer:")
        # print(question_texts[idx])
        print(f"cosine_score:{1-distance}, {corresponding_answer[idx]}")
      else:
        bert_text_search_start_end_QA(input_question, contents)
        print(f'Answer: {answer}')

# %%
############## combination QA chatbot version!!!!!!!!!!!!!!!!!!!!!!!! ##############

question = input("\nPlease enter your question: \n")

while True:
  # question_answer(question)
  combination_model(question, question_embeddings, corresponding_answer)

  flag = True
  flag_N = False
  while flag:
    response = input("\nDo you have other questions? \n ")
    if response not in ["No", "no","not thing", "that's it","N"]:
      # question = input("\nPlease enter your question: \n")
      question = response
      flag = False
    else:
      print("\nSee you next time!")
      flag = False
      flag_N = True
  if flag_N == True:
    break
# Out:
# Please enter your question:
# nba
# Answer: the national basketball association
#
# Do you have other questions?
#  no
#
# See you next time!
